# %% [markdown]
# # MUT Power Up players and their eligible teams (scraped from FootballDB)
# #### - Matt , August 18, 2018<br>
#
# - Made Fixes
# - Added HOF players
# - Added Aug 18 legends
# - Added team captains

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv('powerup_data_aug18.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
numeric_data = data.select_dtypes(include=['int64', 'float64']).drop('OVR', axis=1)
numeric_data.sum().sort_values(ascending=False)
teams = numeric_data.columns
data['numTeams'] = numeric_data.sum(axis=1)

# %%
# Number of teams per power up player
data['numTeams'].value_counts().sort_values(ascending=False)
# Out:
# 2     114
# 4      35
# 6      10
# 8       3
# 10      2
# 12      1
# 14      1
# Name: numTeams, dtype: int64

# %%
data[ data['lastName']=='Sharpe']
# Out:
# Empty DataFrame
# Columns: [Name, OVR, POS, PS4, firstName, lastName, POS2, Player, Pos, College, Teams, Ari, Atl, Bal, Buf, Car, Chi, Cin, Cle, Dal, Den, Det, GB, Hou, Ind, Jax, KC, Mia, Min, NE, NO, NYG, NYJ, Oak, Phi, Pit, SF, Sea, TB, Ten, Was, RAMS, CHARGERS, numTeams]
# Index: []
#
# [0 rows x 44 columns]

# %%
a = numeric_data.sum().sort_values(ascending=False)[1:]

pal = {'Phi':'xkcd:green', 'NE': 'darkblue', 'NO':'gold', 'GB':'green',
       'Min':'xkcd:purple', 'Was':'maroon', 'Ten': 'cyan', 'TB':'xkcd:crimson',
       'Sea':'chartreuse', 'CHARGERS':'xkcd:azure', 'Atl':'xkcd:red',
       'Bal':'indigo', 'RAMS':'xkcd:khaki', 'KC':'red', 'NYJ': 'darkgreen',
       'Jax':'xkcd:darkgreen', 'Oak':'grey', 'Buf':'xkcd:blue', 'Car':'aqua',
       'Cle':'chocolate', 'Pit':'yellow', 'NYG':'blue', 'SF':'xkcd:gold',
       'Chi':'xkcd:orange', 'Dal':'xkcd:darkblue', 'Mia':'xkcd:aqua',
       'Den':'xkcd:orangered', 'Hou':'xkcd:navy', 'Ari':'xkcd:red',
       'Cin':'xkcd:orange', 'Det':'xkcd:lightblue', 'Ind':'xkcd:azure'}

# %%
plt.figure(figsize=(15, 10))
ax = sns.barplot(x=a.values, y=a.index, palette=pal)
ax.set_title('Number of Power Up Players Eligible for Each Team');

# %%
data.to_csv('powerup_aug18.csv')
small_data = data[['Name','POS','Teams', 'numTeams']]
small_data.to_csv('small_powerup_data.csv')

# %% [markdown]
# ### Biggest journeymen

# %%
small_data['Teams'] = small_data['Teams'].str.replace(',', ', ')
small_data['Teams'] = small_data['Teams'].str.replace('NFLEHam', ' ')
small_data[ small_data['numTeams'] >= 4].sort_values('numTeams', ascending=False)
# Out:
#                   Name   POS                           Teams  numTeams
# 7         Lorenzo Neal    FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 1           Randy Moss    WR      Min, Oak, NE, Min, Ten, SF        12
# 110     Rashaan Melvin    CB           TB, Bal, NE, Ind, Oak        10
# 157      Terrell Owens    WR      SF,  Phi,  Dal,  Buf,  Cin        10
# 43       Demario Davis   MLB               NYJ, Cle, NYJ, NO         8
# 159        Rod Woodson    CB            Pit,  SF,  Bal,  Oak         8
# 2         Michael Vick    QB              Atl, Phi, NYJ, Pit         8
# 5        Ted Hendricks  LOLB               Bal, GB, Oak, LAR         6
# 6     Steve Hutchinson    LG                   Sea, Min, Ten         6
# 138      Ndamukong Suh    DT                    Det, Mia, LA         6
# 64        Brent Grimes    CB                 Atl, Mia, TB,           6
# 61        Jimmy Graham    TE                     NO, Sea, GB         6
# 31          Zach Brown   MLB                               0         6
# 127      Jabaal Sheard    RE                    Cle, NE, Ind         6
# 163         Jerry Rice    WR                  SF,  Oak,  Sea         6
# 3         Reggie White    LE                    Phi, GB, Car         6
# 130        Josh Sitton    LG                    GB, Chi, Mia         6
# 115    Kelechi Osemele    LG                        Bal, Oak         4
# 116       Jason Peters    LT                      Buf, , Phi         4
# 114         Greg Olsen    TE                        Chi, Car         4
# 117      Marcus Peters    CB                          KC, LA         4
# 113     Andrew Norwell    LG                        Car, Jax         4
# 0         Champ Bailey    CB                        Was, Den         4
# 128    Richard Sherman    CB                         Sea, SF         4
# 139    Golden Tate III    WR                               0         4
# 107     Tyrann Mathieu    FS                        Ari, Hou         4
# 147     Delanie Walker    TE                         SF, Ten         4
# 154      Kevin Zeitler    RG                        Cin, Cle         4
# 160      Demarcus Ware  ROLB                       Dal,  Den         4
# 161          Tim Brown    WR                        Oak,  TB         4
# 144    Danny Trevathan   MLB                        Den, Chi         4
# 86    Trumaine Johnson    CB                               0         4
# 104          Alex Mack     C                        Cle, Atl         4
# 99       Jarvis Landry    WR                        Mia, Cle         4
# 8          Willie Roaf    LT                          NO, KC         4
# 9          Bruce Smith    RE                        Buf, Was         4
# 11         Steve Young    QB                          TB, SF         4
# 26          A.J. Bouye    CB                        Hou, Jax         4
# 27       Nigel Bradham  LOLB                        Buf, Phi         4
# 29          Drew Brees    QB                          SD, NO         4
# 32      Malcolm Butler    CB                         NE, Ten         4
# 34     Calais Campbell    LE                        Ari, Jax         4
# 58     Stephon Gilmore    CB                         Buf, NE         4
# 68   Damon Harrison Sr    DT                               0         4
# 69       Casey Hayward    CB                     GB, SD, LAC         4
# 77       Rodney Hudson     C                         KC, Oak         4
# 79          Micah Hyde    SS                         GB, Buf         4
# 82     Janoris Jenkins    CB                        Stl, NYG         4
# 83     Malcolm Jenkins    SS                         NO, Phi         4
# 91       Linval Joseph    DT                        NYG, Min         4
# 93       Kyle Juszczyk    FB                         Bal, SF         4
# 164     Shannon Sharpe    TE                       Den,  Bal         4

# %%
team_abbrevs = list(pal.keys())
team_list = []

data.reset_index(drop=True, inplace=True)
small_data.reset_index(drop=True, inplace=True)

for team in team_abbrevs:
    current_team = data[ data[team]==1]
    indices = current_team.index.values
    team_list.append(small_data.iloc[indices])

# %% [markdown]
# ## Team Lists

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/167/thumbs/960.gif)

# %%
i=0
team_list[i]
# Out:
#                 Name   POS                       Teams  numTeams
# 2       Michael Vick    QB          Atl, Phi, NYJ, Pit         8
# 3       Reggie White    LE                Phi, GB, Car         6
# 27     Nigel Bradham  LOLB                    Buf, Phi         4
# 41      Fletcher Cox    DT                         Phi         2
# 51         Zach Ertz    TE                         Phi         2
# 60    Brandon Graham    LE                         Phi         2
# 71      Jordan Hicks   MLB                         Phi         2
# 83   Malcolm Jenkins    SS                     NO, Phi         4
# 85      Lane Johnson    RT                           0         2
# 95       Jason Kelce     C                         Phi         2
# 116     Jason Peters    LT                  Buf, , Phi         4
# 149     Carson Wentz    QB                         Phi         2
# 157    Terrell Owens    WR  SF,  Phi,  Dal,  Buf,  Cin        10

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/151/thumbs/y71myf8mlwlk8lbgagh3fd5e0.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# NE
#                 Name POS                       Teams  numTeams
# 1         Randy Moss  WR  Min, Oak, NE, Min, Ten, SF        12
# 16     David Andrews   C                          NE         2
# 28         Tom Brady  QB                          NE         2
# 32    Malcolm Butler  CB                     NE, Ten         4
# 45     James Develin  FB                        , NE         2
# 49    Julian Edelman  WR                        , NE         2
# 58   Stephon Gilmore  CB                     Buf, NE         4
# 65    Rob Gronkowski  TE                          NE         2
# 108   Devin McCourty  FS                          NE         2
# 110   Rashaan Melvin  CB       TB, Bal, NE, Ind, Oak        10
# 127    Jabaal Sheard  RE                Cle, NE, Ind         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/175/thumbs/907.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# NO
#                   Name  POS                           Teams  numTeams
# 7         Lorenzo Neal   FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 8          Willie Roaf   LT                          NO, KC         4
# 29          Drew Brees   QB                          SD, NO         4
# 43       Demario Davis  MLB               NYJ, Cle, NYJ, NO         8
# 61        Jimmy Graham   TE                     NO, Sea, GB         6
# 83     Malcolm Jenkins   SS                         NO, Phi         4
# 90      Cameron Jordan   LE                              NO         2
# 94        Alvin Kamara   HB                              NO         2
# 100  Marshon Lattimore   CB                              NO         2
# 119       Ryan Ramczyk   RT                              NO         2
# 143     Michael Thomas   WR                              NO         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/171/thumbs/dcy03myfhffbki5d7il3.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# GB
#                 Name   POS              Teams  numTeams
# 3       Reggie White    LE       Phi, GB, Car         6
# 5      Ted Hendricks  LOLB  Bal, GB, Oak, LAR         6
# 12     Davante Adams    WR                 GB         2
# 18   David Bakhtiari    LT                 GB         2
# 37       Kenny Clark    DT                 GB         2
# 61      Jimmy Graham    TE        NO, Sea, GB         6
# 69     Casey Hayward    CB        GB, SD, LAC         4
# 79        Micah Hyde    SS            GB, Buf         4
# 123    Aaron Rodgers    QB                 GB         2
# 130      Josh Sitton    LG       GB, Chi, Mia         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/172/thumbs/17227042013.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Min
#                  Name   POS          Teams  numTeams
# 6    Steve Hutchinson    LG  Sea, Min, Ten         6
# 20       Anthony Barr  ROLB            Min         2
# 46       Stefon Diggs    WR            Min         2
# 63    Everson Griffen    RE            Min         2
# 91      Linval Joseph    DT       NYG, Min         4
# 122     Xavier Rhodes    CB            Min         2
# 132    Harrison Smith    FS            Min         2
# 140      Adam Thielen    WR            Min         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/168/thumbs/im5xz2q9bjbg44xep08bf5czq.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Was
#                 Name   POS     Teams  numTeams
# 0       Champ Bailey    CB  Was, Den         4
# 9        Bruce Smith    RE  Buf, Was         4
# 10       Sean Taylor    FS       Was         2
# 31        Zach Brown   MLB         0         6
# 97     Ryan Kerrigan  LOLB       Was         2
# 121      Jordan Reed    TE       Was         2
# 126  Brandon Scherff    RG       Was         2
# 151   Trent Williams    LT         0         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/160/thumbs/1053.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Ten
#                  Name  POS                           Teams  numTeams
# 1          Randy Moss   WR      Min, Oak, NE, Min, Ten, SF        12
# 6    Steve Hutchinson   LG                   Sea, Min, Ten         6
# 7        Lorenzo Neal   FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 31         Zach Brown  MLB                               0         6
# 32     Malcolm Butler   CB                         NE, Ten         4
# 33        Kevin Byard   FS                             Ten         2
# 35      Jurrell Casey   RE                             Ten         2
# 102      Taylor Lewan   LT                             Ten         2
# 147    Delanie Walker   TE                         SF, Ten         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/176/thumbs/17636702014.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# TB
#                Name   POS                           Teams  numTeams
# 4    Derrick Brooks  ROLB                              TB         2
# 7      Lorenzo Neal    FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 11      Steve Young    QB                          TB, SF         4
# 42    Lavonte David  ROLB                              TB         2
# 48     Demar Dotson    RT                            , TB         2
# 52       Mike Evans    WR                              TB         2
# 64     Brent Grimes    CB                 Atl, Mia, TB,           6
# 109    Gerald McCoy    DT                              TB         2
# 110  Rashaan Melvin    CB           TB, Bal, NE, Ind, Oak        10
# 161       Tim Brown    WR                        Oak,  TB         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/180/thumbs/pfiobtreaq7j0pzvadktsc6jv.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Sea
#                  Name  POS           Teams  numTeams
# 6    Steve Hutchinson   LG   Sea, Min, Ten         6
# 19       Doug Baldwin   WR             Sea         2
# 36     Kam Chancellor   SS             Sea         2
# 61       Jimmy Graham   TE     NO, Sea, GB         6
# 128   Richard Sherman   CB         Sea, SF         4
# 139   Golden Tate III   WR               0         4
# 142   Earl Thomas III   FS               0         2
# 146      Bobby Wagner  MLB             Sea         2
# 152    Russell Wilson   QB             Sea         2
# 163        Jerry Rice   WR  SF,  Oak,  Sea         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/6446/thumbs/644624152017.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# CHARGERS
#              Name POS                           Teams  numTeams
# 7    Lorenzo Neal  FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 14   Keenan Allen  WR                         SD, LAC         2
# 25      Joey Bosa  LE                         SD, LAC         2
# 29     Drew Brees  QB                          SD, NO         4
# 59  Melvin Gordon  HB                         SD, LAC         2
# 69  Casey Hayward  CB                     GB, SD, LAC         4
# 70   Hunter Henry  TE                         SD, LAC         2
# 80  Melvin Ingram  RE                         SD, LAC         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/173/thumbs/299.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Atl
#                 Name  POS               Teams  numTeams
# 2       Michael Vick   QB  Atl, Phi, NYJ, Pit         8
# 56   Devonta Freeman   HB                 Atl         2
# 64      Brent Grimes   CB     Atl, Mia, TB,           6
# 87       Deion Jones  MLB                 Atl         2
# 88       Julio Jones   WR                 Atl         2
# 104        Alex Mack    C            Cle, Atl         4
# 125        Matt Ryan   QB                 Atl         2
# 145  Desmond Trufant   CB                 Atl         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/153/thumbs/318.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Bal
#                 Name   POS                           Teams  numTeams
# 5      Ted Hendricks  LOLB               Bal, GB, Oak, LAR         6
# 7       Lorenzo Neal    FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 93     Kyle Juszczyk    FB                         Bal, SF         4
# 110   Rashaan Melvin    CB           TB, Bal, NE, Ind, Oak        10
# 115  Kelechi Osemele    LG                        Bal, Oak         4
# 133      Jimmy Smith    CB                               0         2
# 137    Terrell Suggs  ROLB                             Bal         2
# 153    Marshal Yanda    RG                             Bal         2
# 159      Rod Woodson    CB            Pit,  SF,  Bal,  Oak         8
# 162        Ray Lewis   MLB                             Bal         2
# 164   Shannon Sharpe    TE                       Den,  Bal         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/5941/thumbs/594179532017.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# RAMS
#                  Name POS         Teams  numTeams
# 47       Aaron Donald  RE       Stl, LA         2
# 66     Todd Gurley II  HB             0         2
# 82    Janoris Jenkins  CB      Stl, NYG         4
# 86   Trumaine Johnson  CB             0         4
# 92    Lamarcus Joyner  FS       Stl, LA         2
# 117     Marcus Peters  CB        KC, LA         4
# 138     Ndamukong Suh  DT  Det, Mia, LA         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/162/thumbs/857.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# KC
#                Name   POS    Teams  numTeams
# 8       Willie Roaf    LT   NO, KC         4
# 23       Eric Berry    SS       KC         2
# 72      Tyreek Hill    WR       KC         2
# 75   Justin Houston  LOLB       KC         2
# 77    Rodney Hudson     C  KC, Oak         4
# 78      Kareem Hunt    HB       KC         2
# 96     Travis Kelce    TE       KC         2
# 117   Marcus Peters    CB   KC, LA         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/152/thumbs/v7tehkwthrwefgounvi7znf5k.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# NYJ
#                  Name POS                           Teams  numTeams
# 2        Michael Vick  QB              Atl, Phi, NYJ, Pit         8
# 7        Lorenzo Neal  FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 13        Jamal Adams  SS                             NYJ         2
# 68  Damon Harrison Sr  DT                               0         4
# 86   Trumaine Johnson  CB                               0         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/159/thumbs/15988562013.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Jax
#                   Name   POS     Teams  numTeams
# 26          A.J. Bouye    CB  Hou, Jax         4
# 34     Calais Campbell    LE  Ari, Jax         4
# 54   Leonard Fournette    HB       Jax         2
# 81          Myles Jack  LOLB       Jax         2
# 113     Andrew Norwell    LG  Car, Jax         4
# 120       Jalen Ramsey    CB       Jax         2
# 134       Telvin Smith  ROLB         0         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/163/thumbs/g9mgk6x3ge26t44cccm9oq1vl.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Oak
#                 Name   POS                       Teams  numTeams
# 1         Randy Moss    WR  Min, Oak, NE, Min, Ten, SF        12
# 5      Ted Hendricks  LOLB           Bal, GB, Oak, LAR         6
# 40      Amari Cooper    WR                         Oak         2
# 77     Rodney Hudson     C                     KC, Oak         4
# 105      Khalil Mack    LE                         Oak         2
# 110   Rashaan Melvin    CB       TB, Bal, NE, Ind, Oak        10
# 115  Kelechi Osemele    LG                    Bal, Oak         4
# 159      Rod Woodson    CB        Pit,  SF,  Bal,  Oak         8
# 161        Tim Brown    WR                    Oak,  TB         4
# 163       Jerry Rice    WR              SF,  Oak,  Sea         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/149/thumbs/n0fd1z6xmhigb0eej3323ebwq.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Buf
#                 Name   POS                       Teams  numTeams
# 9        Bruce Smith    RE                    Buf, Was         4
# 27     Nigel Bradham  LOLB                    Buf, Phi         4
# 31        Zach Brown   MLB                           0         6
# 58   Stephon Gilmore    CB                     Buf, NE         4
# 79        Micah Hyde    SS                     GB, Buf         4
# 116     Jason Peters    LT                  Buf, , Phi         4
# 157    Terrell Owens    WR  SF,  Phi,  Dal,  Buf,  Cin        10

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/174/thumbs/f1wggq2k8ql88fe33jzhw641u.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Car
#                Name  POS         Teams  numTeams
# 3      Reggie White   LE  Phi, GB, Car         6
# 98     Luke Kuechly  MLB           Car         2
# 112      Cam Newton   QB           Car         2
# 113  Andrew Norwell   LG      Car, Jax         4
# 114      Greg Olsen   TE      Chi, Car         4
# 129    Kawann Short   DT           Car         2
# 150  Daryl Williams   RT           Car         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/155/thumbs/15578552015.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Cle
#               Name  POS              Teams  numTeams
# 24    Joel Bitonio   LG                Cle         2
# 43   Demario Davis  MLB  NYJ, Cle, NYJ, NO         8
# 99   Jarvis Landry   WR           Mia, Cle         4
# 104      Alex Mack    C           Cle, Atl         4
# 127  Jabaal Sheard   RE       Cle, NE, Ind         6
# 154  Kevin Zeitler   RG           Cin, Cle         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/156/thumbs/970.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Pit
#                    Name POS                 Teams  numTeams
# 2          Michael Vick  QB    Atl, Phi, NYJ, Pit         8
# 22         Le'Veon Bell  HB                   Pit         2
# 30        Antonio Brown  WR                   Pit         2
# 44       David DeCastro  RG                   Pit         2
# 57       Marcus Gilbert  RT                   Pit         2
# 124  Ben Roethlisberger  QB                   Pit         2
# 159         Rod Woodson  CB  Pit,  SF,  Bal,  Oak         8

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/166/thumbs/919.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# NYG
#                   Name POS     Teams  numTeams
# 21    Odell Beckham Jr  WR         0         2
# 39      Landon Collins  SS       NYG         2
# 68   Damon Harrison Sr  DT         0         4
# 82     Janoris Jenkins  CB  Stl, NYG         4
# 91       Linval Joseph  DT  NYG, Min         4
# 165    Michael Strahan  LE       NYG         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/179/thumbs/17994552009.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# SF
#                 Name POS                       Teams  numTeams
# 1         Randy Moss  WR  Min, Oak, NE, Min, Ten, SF        12
# 11       Steve Young  QB                      TB, SF         4
# 93     Kyle Juszczyk  FB                     Bal, SF         4
# 128  Richard Sherman  CB                     Sea, SF         4
# 147   Delanie Walker  TE                     SF, Ten         4
# 157    Terrell Owens  WR  SF,  Phi,  Dal,  Buf,  Cin        10
# 159      Rod Woodson  CB        Pit,  SF,  Bal,  Oak         8
# 163       Jerry Rice  WR              SF,  Oak,  Sea         6

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/169/thumbs/364.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Chi
#                 Name  POS         Teams  numTeams
# 15       Adrian Amos   SS           Chi         2
# 76     Jordan Howard   HB           Chi         2
# 114       Greg Olsen   TE      Chi, Car         4
# 130      Josh Sitton   LG  GB, Chi, Mia         6
# 144  Danny Trevathan  MLB      Den, Chi         4
# 158   Brian Urlacher  MLB           Chi         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/165/thumbs/406.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Dal
#                  Name   POS                       Teams  numTeams
# 50    Ezekiel Elliott    HB                         Dal         2
# 55   Travis Frederick     C                         Dal         2
# 101          Sean Lee  ROLB                       , Dal         2
# 106       Zack Martin    RG                         Dal         2
# 135       Tyron Smith    LT                           0         2
# 157     Terrell Owens    WR  SF,  Phi,  Dal,  Buf,  Cin        10
# 160     Demarcus Ware  ROLB                   Dal,  Den         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/150/thumbs/15073062018.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Mia
#               Name POS            Teams  numTeams
# 64    Brent Grimes  CB  Atl, Mia, TB,           6
# 89    Reshad Jones  SS                0         2
# 99   Jarvis Landry  WR         Mia, Cle         4
# 130    Josh Sitton  LG     GB, Chi, Mia         6
# 138  Ndamukong Suh  DT     Det, Mia, LA         6
# 156     Dan Marino  QB              Mia         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/161/thumbs/9ebzja2zfeigaziee8y605aqp.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Den
#                  Name   POS      Teams  numTeams
# 0        Champ Bailey    CB   Was, Den         4
# 67    Chris Harris Jr    CB          0         2
# 111        Von Miller  LOLB        Den         2
# 141  Demaryius Thomas    WR        Den         2
# 144   Danny Trevathan   MLB   Den, Chi         4
# 155     Terrell Davis    RB        Den         2
# 160     Demarcus Ware  ROLB  Dal,  Den         4
# 164    Shannon Sharpe    TE  Den,  Bal         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/157/thumbs/570.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Hou
#                  Name   POS     Teams  numTeams
# 26         A.J. Bouye    CB  Hou, Jax         4
# 38   Jadeveon Clowney  ROLB       Hou         2
# 74    DeAndre Hopkins    WR       Hou         2
# 107    Tyrann Mathieu    FS  Ari, Hou         4
# 148         J.J. Watt    LE       Hou         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/177/thumbs/kwth8f1cfa2sch5xhjjfaof90.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Ari
#                  Name POS     Teams  numTeams
# 34    Calais Campbell  LE  Ari, Jax         4
# 53   Larry Fitzgerald  WR       Ari         2
# 84      David Johnson  HB       Ari         2
# 107    Tyrann Mathieu  FS  Ari, Hou         4
# 118  Patrick Peterson  CB       Ari         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/154/thumbs/403.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Cin
#               Name POS                           Teams  numTeams
# 7     Lorenzo Neal  FB  NO, NYJ, TB, Ten, Cin, SD, Bal        14
# 17     Geno Atkins  DT                             Cin         2
# 62      A.J. Green  WR                             Cin         2
# 154  Kevin Zeitler  RG                        Cin, Cle         4
# 157  Terrell Owens  WR      SF,  Phi,  Dal,  Buf,  Cin        10

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/170/thumbs/17013982017.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Det
#                  Name POS         Teams  numTeams
# 131    Darius Slay Jr  CB             0         2
# 136  Matthew Stafford  QB           Det         2
# 138     Ndamukong Suh  DT  Det, Mia, LA         6
# 139   Golden Tate III  WR             0         4

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/158/thumbs/593.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# Ind
#                Name POS                  Teams  numTeams
# 73      T.Y. Hilton  WR                    Ind         2
# 103     Andrew Luck  QB                  , Ind         2
# 110  Rashaan Melvin  CB  TB, Bal, NE, Ind, Oak        10
# 127   Jabaal Sheard  RE           Cle, NE, Ind         6
