# %% [markdown]
# # MUT Power Up players and their eligible teams (scraped from FootballDB)
# #### - Matt , last updated: Oct 20, 2018<br>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv('mut_playas.csv')
df = pd.concat( [data, data['String / Filter'].str.replace(',', '|').str.get_dummies()], axis=1)
numeric_data = df.select_dtypes(include=[float, int])
obj_data = df.select_dtypes(exclude=[float, int])
numeric_data.drop('n/a', axis=1, inplace=True)
numeric_data['numTeams'] = numeric_data.sum(axis=1).astype(int)
players = pd.concat([obj_data, numeric_data], axis=1)

# %%
data.to_csv('player_data_.csv')

# %%
data.shape
# Out:
# (193, 12)

# %%
plt.figure(figsize=(13, 7))
sns.countplot(data['Position']);
plt.title('Number of Power-Up Players by Position');

# %%
# Number of teams per power up player
plt.figure(figsize=(13, 4))
sns.countplot(players['numTeams']);
plt.title('Power-Up Players Binned by Number of Teams Played For');

# %%
numeric_data = players.select_dtypes(include=[float, int])

a = numeric_data.sum().sort_values(ascending=False)[1:]

pal = {'PHI':'xkcd:green', 'NE': 'darkblue', 'NO':'gold', 'GB':'green',
       'MIN':'xkcd:purple', 'WAS':'maroon', 'TEN': 'cyan', 'TB':'xkcd:crimson',
       'SEA':'chartreuse', 'LAC':'xkcd:azure', 'ATL':'xkcd:red',
       'BAL':'indigo', 'LAR':'xkcd:khaki', 'KC':'red', 'NYJ': 'darkgreen',
       'JAX':'xkcd:darkgreen', 'OAK':'grey', 'BUF':'xkcd:blue', 'CAR':'aqua',
       'CLE':'chocolate', 'PIT':'xkcd:yellow', 'NYG':'blue', 'SF':'xkcd:gold',
       'CHI':'xkcd:orange', 'DAL':'xkcd:darkblue', 'MIA':'xkcd:aqua',
       'DEN':'xkcd:orangered', 'HOU':'xkcd:navy', 'ARI':'xkcd:red',
       'CIN':'xkcd:orange', 'DET':'xkcd:lightblue', 'IND':'xkcd:azure'}

# %%
plt.figure(figsize=(15, 10))
ax = sns.barplot(x=a.values, y=a.index, palette=pal)
for p in ax.patches:
    if np.isnan(p.get_width()):
        gh = 0.0
    else:
        gh = np.round(p.get_width(), 2)
                
    ax.annotate(int(gh), (np.round(gh+0.15, 3), p.get_y()+0.5))
ax.set_title('Number of Power Up Players Eligible for Each Team');

# %% [markdown]
# ### Biggest journeymen

# %%
small = pd.concat([obj_data[['Name', 'Position', 'Type', 'String / Filter']], players['numTeams']], axis=1)
small['String / Filter'] = small['String / Filter'].str.replace('n/a,', '')
small[ small['numTeams'] >= 4].sort_values('numTeams', ascending=False)
# Out:
#                Name Position       Type            String / Filter  numTeams
# 105    Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 85    Deion Sanders       CB  Legend PU         ATL,SF,DAL,WAS,BAL         5
# 100      Randy Moss       WR  Legend PU          MIN,OAK,NE,TEN,SF         5
# 117    Terell Owens       WR        HoF         SF,PHI,DAL,BUF,CIN         5
# 149  Rashaan Melvin       CB   Power Up          OAK,TB,BAL,NE,IND         5
# 84     Michael Vick       QB  Legend PU            ATL,PHI,NYJ,PIT         4
# 98     Kevin Greene     LOLB  Legend PU             LAR,PIT,CAR,SF         4
# 114     Rod Woodson       CB        HoF             PIT,SF,BAL,OAK         4

# %%
team_abbrevs = list(pal.keys())
team_list = []

players.reset_index(drop=True, inplace=True)
small.reset_index(drop=True, inplace=True)

for team in team_abbrevs:
    current_team = players[ players[team]==1]
    indices = current_team.index.values
    team_list.append(small.iloc[indices])

# %% [markdown]
# # Team Lists
# **---------------------------------------------------------------**

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/167/thumbs/960.gif)

# %% [markdown]
# ##  Philadelphia Eagles

# %%
i=0
team_list[i]
# Out:
#                Name Position       Type     String / Filter  numTeams
# 84     Michael Vick       QB  Legend PU     ATL,PHI,NYJ,PIT         4
# 111  Donovan McNabb       QB  Legend PU             PHI,MIN         2
# 112   Brian Dawkins       SS  Legend PU             PHI,DEN         2
# 113    Reggie White       LE  Legend PU          PHI,GB,CAR         3
# 117    Terell Owens       WR        HoF  SF,PHI,DAL,BUF,CIN         5
# 150    Fletcher Cox       DT   Power Up                 PHI         1
# 151       Zach Ertz       TE   Power Up                 PHI         1
# 152  Brandon Graham       LE   Power Up                 PHI         1
# 153    Jordan Hicks      MLB   Power Up                 PHI         1
# 154    Lane Johnson       RT   Power Up                 PHI         1
# 155     Jason Kelce        C   Power Up                 PHI         1
# 156    Carson Wentz       QB   Power Up                 PHI         1
# 157   Nigel Bradham     LOLB   Power Up             PHI,BUF         2
# 158    Jason Peters       LT   Power Up             PHI,BUF         2
# 159  Malcom Jenkins       SS   Power Up              PHI,NO         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/151/thumbs/y71myf8mlwlk8lbgagh3fd5e0.gif)

# %% [markdown]
# ## New England Patriots

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type    String / Filter  numTeams
# 49      Jabaal Sheard       RE   Power Up         IND,CLE,NE         3
# 100        Randy Moss       WR  Legend PU  MIN,OAK,NE,TEN,SF         5
# 123     David Andrews        C   Power Up                 NE         1
# 124         Tom Brady       QB   Power Up                 NE         1
# 125     James Develin       FB   Power Up                 NE         1
# 126    Julian Edelman       WR   Power Up                 NE         1
# 127    Rob Gronkowski       TE   Power Up                 NE         1
# 128    Devin McCourty       FS   Power Up                 NE         1
# 129  Dont'a Hightower     LOLB   Power Up                 NE         1
# 130   Stephon Gilmore       CB   Power Up             NE,BUF         2
# 149    Rashaan Melvin       CB   Power Up  OAK,TB,BAL,NE,IND         5
# 181    Malcolm Butler       CB   Power Up             TEN,NE         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/175/thumbs/907.gif)

# %% [markdown]
# ## New Orleans Saints

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type            String / Filter  numTeams
# 42       Jimmy Graham       TE   Power Up                  GB,NO,SEA         3
# 102     La'Roi Glover       DT     Legend                         NO         1
# 103       Willie Roaf       LT  Legend PU                      NO,KC         2
# 104    Ricky Williams       HB     Master                 NO,MIA,BAL         3
# 105      Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 131    Cameron Jordan       LE   Power Up                         NO         1
# 132      Alvin Kamara       HB   Power Up                         NO         1
# 133  Marson Lattimore       CB   Power Up                         NO         1
# 134      Ryan Ramczyk       RT   Power Up                         NO         1
# 135    Michael Thomas       WR   Power Up                         NO         1
# 136        Drew Brees       QB   Power Up                     NO,LAC         2
# 137     Demario Davis      MLB   Power Up                 NO,NYJ,CLE         3
# 159    Malcom Jenkins       SS   Power Up                     PHI,NO         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/171/thumbs/dcy03myfhffbki5d7il3.gif)

# %% [markdown]
# ## Green Bay Packers

# %%
i+=1
team_list[i]
# Out:
#                   Name Position       Type String / Filter  numTeams
# 12          Micah Hyde       SS   Power Up          BUF,GB         2
# 37       Davante Adams       WR   Power Up              GB         1
# 38     David Bakhtiari       LT   Power Up              GB         1
# 39         Kenny Clark       DT   Power Up              GB         1
# 40       Aaron Rodgers       QB   Power Up              GB         1
# 41   Ha Ha Clinton-Dix       FS   Power Up              GB         1
# 42        Jimmy Graham       TE   Power Up       GB,NO,SEA         3
# 68       Casey Hayward       CB   Power Up          LAC,GB         2
# 75         Josh Sitton       LG   Power Up      MIA,GB,CHI         3
# 96       Ted Hendricks     LOLB  Legend PU      IND,GB,OAK         3
# 113       Reggie White       LE  Legend PU      PHI,GB,CAR         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/172/thumbs/17227042013.gif)

# %% [markdown]
# ## Minnesota Vikings

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type    String / Filter  numTeams
# 76       Anthony Barr     ROLB   Power Up                MIN         1
# 77       Stefon Diggs       WR   Power Up                MIN         1
# 78    Everson Griffen       RE   Power Up                MIN         1
# 79      Xavier Rhodes       CB   Power Up                MIN         1
# 80     Harrison Smith       FS   Power Up                MIN         1
# 81       Adam Thielen       WR   Power Up                MIN         1
# 82      Linval Joseph       DT   Power Up            MIN,NYG         2
# 100        Randy Moss       WR  Legend PU  MIN,OAK,NE,TEN,SF         5
# 101       John Randle       DT  Legend PU            MIN,SEA         2
# 111    Donovan McNabb       QB  Legend PU            PHI,MIN         2
# 115  Steve Hutchinson       LG  Legend PU        SEA,MIN,TEN         3
# 189  Randall McDaniel       LG     Legend                MIN         1
# 191       Paul Krause       FS  Legend PU            WAS,MIN         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/168/thumbs/im5xz2q9bjbg44xep08bf5czq.gif)

# %% [markdown]
# ## Washington Redskins

# %%
i+=1
team_list[i]
# Out:
#                 Name Position       Type     String / Filter  numTeams
# 85     Deion Sanders       CB  Legend PU  ATL,SF,DAL,WAS,BAL         5
# 88       Bruce Smith       RE  Legend PU             BUF,WAS         2
# 121      Sean Taylor       FS  Legend PU                 WAS         1
# 122     Champ Bailey       CB  Legend PU             WAS,DEN         2
# 183    Ryan Kerrigan     LOLB   Power Up                 WAS         1
# 184      Jordan Reed       TE   Power Up                 WAS         1
# 185  Brandon Scherff       RG   Power Up                 WAS         1
# 186   Trent Williams       LT   Power Up                 WAS         1
# 187       Zach Brown      MLB   Power Up         WAS,TEN,BUF         3
# 191      Paul Krause       FS  Legend PU             WAS,MIN         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/160/thumbs/1053.gif)

# %% [markdown]
# ## Tennessee Titans

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type            String / Filter  numTeams
# 100        Randy Moss       WR  Legend PU          MIN,OAK,NE,TEN,SF         5
# 105      Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 115  Steve Hutchinson       LG  Legend PU                SEA,MIN,TEN         3
# 120      Eddie George       HB     Legend                        TEN         1
# 178       Kevin Byard       FS   Power Up                        TEN         1
# 179      Jurell Casey       RE   Power Up                        TEN         1
# 180      Taylor Lewan       LT   Power Up                        TEN         1
# 181    Malcolm Butler       CB   Power Up                     TEN,NE         2
# 182    Delanie Walker       TE   Power Up                     TEN,SF         2
# 187        Zach Brown      MLB   Power Up                WAS,TEN,BUF         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/176/thumbs/17636702014.gif)

# %% [markdown]
# ## Tampa Bay Buccaneers

# %%
i+=1
team_list[i]
# Out:
#                Name Position       Type            String / Filter  numTeams
# 105    Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 110       Tim Brown       WR  Legend PU                     OAK,TB         2
# 118  Derrick Brooks     ROLB  Legend PU                         TB         1
# 119     Steve Young       QB  Legend PU                      TB,SF         2
# 149  Rashaan Melvin       CB   Power Up          OAK,TB,BAL,NE,IND         5
# 173   Lavonte David     ROLB   Power Up                         TB         1
# 174    Demar Dotson       RT   Power Up                         TB         1
# 175      Mike Evans       WR   Power Up                         TB         1
# 176    Gerald McCoy       DT   Power Up                         TB         1
# 177    Brent Grimes       CB   Power Up                 TB,ATL,MIA         3
# 188    Ronde Barber       CB  Legend PU                         TB         1

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/180/thumbs/pfiobtreaq7j0pzvadktsc6jv.gif)

# %% [markdown]
# ## Seattle Seahawks

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type String / Filter  numTeams
# 36    Golden Tate III       WR   Power Up         DET,SEA         2
# 42       Jimmy Graham       TE   Power Up       GB,NO,SEA         3
# 101       John Randle       DT  Legend PU         MIN,SEA         2
# 115  Steve Hutchinson       LG  Legend PU     SEA,MIN,TEN         3
# 116        Jerry Rice       WR    Captain      SF,OAK,SEA         3
# 166      Doug Baldwin       WR   Power Up             SEA         1
# 167    Kam Chancellor       SS   Power Up             SEA         1
# 168   Earl Thomas III       FS   Power Up             SEA         1
# 169      Bobby Wagner      MLB   Power Up             SEA         1
# 170    Russell Wilson       QB   Power Up             SEA         1
# 172   Richard Sherman       CB   Power Up          SF,SEA         2
# 192     Franco Harris       FB  Legend PU         PIT,SEA         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/6446/thumbs/644624152017.gif)

# %% [markdown]
# ## Los Angeles Chargers

# %%
i+=1
team_list[i]
# Out:
#               Name Position       Type            String / Filter  numTeams
# 63    Keenan Allan       WR   Power Up                        LAC         1
# 64       Joey Bosa       LE   Power Up                        LAC         1
# 65   Melvin Gordon       HB   Power Up                        LAC         1
# 66    Hunter Henry       TE   Power Up                        LAC         1
# 67   Melvin Ingram       RE   Power Up                        LAC         1
# 68   Casey Hayward       CB   Power Up                     LAC,GB         2
# 105   Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 136     Drew Brees       QB   Power Up                     NO,LAC         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/173/thumbs/299.gif)

# %% [markdown]
# ## Atlanta Falcons

# %%
i+=1
team_list[i]
# Out:
#                 Name Position       Type     String / Filter  numTeams
# 3    Devonta Freeman       HB   Power Up                 ATL         1
# 4        Deion Jones      MLB   Power Up                 ATL         1
# 5        Julio Jones       WR   Power Up                 ATL         1
# 6          Matt Ryan       QB   Power Up                 ATL         1
# 7    Desmond Trufant       CB   Power Up                 ATL         1
# 8          Alex Mack        C   Power Up             ATL,CLE         2
# 84      Michael Vick       QB  Legend PU     ATL,PHI,NYJ,PIT         4
# 85     Deion Sanders       CB  Legend PU  ATL,SF,DAL,WAS,BAL         5
# 97     Tony Gonzalez       TE  Legend PU              KC,ATL         2
# 177     Brent Grimes       CB   Power Up          TB,ATL,MIA         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/153/thumbs/318.gif)

# %% [markdown]
# ## Baltimore Ravens

# %%
i+=1
team_list[i]
# Out:
#                 Name Position       Type            String / Filter  numTeams
# 9        Jimmy Smith       CB   Power Up                        BAL         1
# 10     Terrell Suggs     ROLB   Power Up                        BAL         1
# 11     Marshal Yanda       RG   Power Up                        BAL         1
# 85     Deion Sanders       CB  Legend PU         ATL,SF,DAL,WAS,BAL         5
# 86         Ray Lewis      MLB    Captain                        BAL         1
# 87    Jonathan Ogden       LT  Legend PU                        BAL         1
# 94    Shannon Sharpe       TE    Captain                    DEN,BAL         2
# 104   Ricky Williams       HB     Master                 NO,MIA,BAL         3
# 105     Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 114      Rod Woodson       CB        HoF             PIT,SF,BAL,OAK         4
# 147  Kelechi Osemele       LG   Power Up                    OAK,BAL         2
# 149   Rashaan Melvin       CB   Power Up          OAK,TB,BAL,NE,IND         5
# 171    Kyle Juszczyk       FB   Power Up                     SF,BAL         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/5941/thumbs/594179532017.gif)

# %% [markdown]
# ## Los Angeles Rams

# %%
i+=1
team_list[i]
# Out:
#                  Name Position       Type String / Filter  numTeams
# 69       Aaron Donald       DT   Power Up             LAR         1
# 70     Todd Gurley II       HB   Power Up             LAR         1
# 71    Lamarcus Joyner       FS   Power Up             LAR         1
# 72      Ndamukong Suh       DT   Power Up     LAR,DET,MIA         3
# 73      Marcus Peters       CB   Power Up          LAR,KC         2
# 83    Aeneas Williams       CB  Legend PU         ARI,LAR         2
# 98       Kevin Greene     LOLB  Legend PU  LAR,PIT,CAR,SF         4
# 140   Janoris Jenkins       CB   Power Up         NYG,LAR         2
# 143  Trumaine Johnson       CB   Power Up         NYJ,LAR         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/162/thumbs/857.gif)

# %% [markdown]
# ## Kansas City Chiefs

# %%
i+=1
team_list[i]
# Out:
#                 Name Position       Type String / Filter  numTeams
# 57        Eric Berry       SS   Power Up              KC         1
# 58       Tyreek Hill       WR   Power Up              KC         1
# 59    Justin Houston     LOLB   Power Up              KC         1
# 60       Kareen Hunt       HB   Power Up              KC         1
# 61      Travis Kelce       TE   Power Up              KC         1
# 62   Patrick Mahomes       QB   Power Up              KC         1
# 73     Marcus Peters       CB   Power Up          LAR,KC         2
# 97     Tony Gonzalez       TE  Legend PU          KC,ATL         2
# 103      Willie Roaf       LT  Legend PU           NO,KC         2
# 148    Rodney Hudson        C   Power Up          OAK,KC         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/152/thumbs/v7tehkwthrwefgounvi7znf5k.gif)

# %% [markdown]
# ## Boo York Jets

# %%
i+=1
team_list[i]
# Out:
#                   Name Position       Type            String / Filter  \
# 84        Michael Vick       QB  Legend PU            ATL,PHI,NYJ,PIT
# 105       Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL
# 108        Kevin Mawae        C     Legend                        NYJ
# 137      Demario Davis      MLB   Power Up                 NO,NYJ,CLE
# 141  Damon Harrison Sr       DT   Power Up                    NYG,NYJ
# 142        Jamal Adams       SS   Power Up                        NYJ
# 143   Trumaine Johnson       CB   Power Up                    NYJ,LAR
#
#      numTeams
# 84          4
# 105         7
# 108         1
# 137         3
# 141         2
# 142         1
# 143         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/159/thumbs/15988562013.gif)

# %% [markdown]
# ## Jacksonville Jaguars

# %%
i+=1
team_list[i]
# Out:
#                  Name Position      Type String / Filter  numTeams
# 50  Leonard Fournette       HB  Power Up             JAX         1
# 51         Myles Jack     LOLB  Power Up             JAX         1
# 52       Jalen Ramsey       CB  Power Up             JAX         1
# 53       Telvin Smith     ROLB  Power Up             JAX         1
# 54    Calais Campbell       LE  Power Up         JAX,ARI         2
# 55     Andrew Norwell       LG  Power Up         JAX,CAR         2
# 56           AJ Bouye       CB  Power Up         JAX,HOU         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/163/thumbs/g9mgk6x3ge26t44cccm9oq1vl.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# OAK
#                 Name Position       Type    String / Filter  numTeams
# 96     Ted Hendricks     LOLB  Legend PU         IND,GB,OAK         3
# 100       Randy Moss       WR  Legend PU  MIN,OAK,NE,TEN,SF         5
# 109       Howie Long       RT     Legend                OAK         1
# 110        Tim Brown       WR  Legend PU             OAK,TB         2
# 114      Rod Woodson       CB        HoF     PIT,SF,BAL,OAK         4
# 116       Jerry Rice       WR    Captain         SF,OAK,SEA         3
# 144     Amari Cooper       WR   Power Up                OAK         1
# 145      Khalil Mack       LE   Power Up            CHI,OAK         2
# 146       Derek Carr       QB   Power Up                OAK         1
# 147  Kelechi Osemele       LG   Power Up            OAK,BAL         2
# 148    Rodney Hudson        C   Power Up             OAK,KC         2
# 149   Rashaan Melvin       CB   Power Up  OAK,TB,BAL,NE,IND         5

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/149/thumbs/n0fd1z6xmhigb0eej3323ebwq.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# BUF
#                 Name Position       Type     String / Filter  numTeams
# 12        Micah Hyde       SS   Power Up              BUF,GB         2
# 88       Bruce Smith       RE  Legend PU             BUF,WAS         2
# 117     Terell Owens       WR        HoF  SF,PHI,DAL,BUF,CIN         5
# 130  Stephon Gilmore       CB   Power Up              NE,BUF         2
# 157    Nigel Bradham     LOLB   Power Up             PHI,BUF         2
# 158     Jason Peters       LT   Power Up             PHI,BUF         2
# 187       Zach Brown      MLB   Power Up         WAS,TEN,BUF         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/174/thumbs/f1wggq2k8ql88fe33jzhw641u.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# CAR
#                Name Position       Type String / Filter  numTeams
# 13     Luke Kuechly      MLB   Power Up             CAR         1
# 14       Cam Newton       Qb   Power Up             CAR         1
# 15     Kawann Short       DT   Power Up             CAR         1
# 16   Daryl Williams       RT   Power Up             CAR         1
# 17       Greg Olsen       TE   Power Up         CAR,CHI         2
# 55   Andrew Norwell       LG   Power Up         JAX,CAR         2
# 98     Kevin Greene     LOLB  Legend PU  LAR,PIT,CAR,SF         4
# 113    Reggie White       LE  Legend PU      PHI,GB,CAR         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/155/thumbs/15578552015.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# CLE
#               Name Position      Type String / Filter  numTeams
# 8        Alex Mack        C  Power Up         ATL,CLE         2
# 23    Joel Bitonio       LG  Power Up             CLE         1
# 24   Kevin Zeitler       RG  Power Up         CLE,CIN         2
# 25   Jarvis Landry       WR  Power Up         CLE,MIA         2
# 49   Jabaal Sheard       RE  Power Up      IND,CLE,NE         3
# 137  Demario Davis      MLB  Power Up      NO,NYJ,CLE         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/156/thumbs/970.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# PIT
#                    Name Position       Type  String / Filter  numTeams
# 84         Michael Vick       QB  Legend PU  ATL,PHI,NYJ,PIT         4
# 98         Kevin Greene     LOLB  Legend PU   LAR,PIT,CAR,SF         4
# 114         Rod Woodson       CB        HoF   PIT,SF,BAL,OAK         4
# 160        Ryan Shazier      MLB     Master              PIT         1
# 161        Le'Veon Bell       HB   Power Up              PIT         1
# 162       Antonio Brown       WR   Power Up              PIT         1
# 163      David DeCastro       RG   Power Up              PIT         1
# 164      Marcus Gilbert       RT   Power Up              PIT         1
# 165  Ben Roethlisberger       QB   Power Up              PIT         1
# 190    Dermontti Dawson        C     Legend              PIT         1
# 192       Franco Harris       FB  Legend PU          PIT,SEA         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/166/thumbs/919.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# NYG
#                   Name Position       Type String / Filter  numTeams
# 82       Linval Joseph       DT   Power Up         MIN,NYG         2
# 106    Michael Strahan       LE    Captain             NYG         1
# 107    Lawrence Taylor     ROLB  Legend PU             NYG         1
# 138   Odell Beckham Jr       WR   Power Up             NYG         1
# 139     Landon Collins       SS   Power Up             NYG         1
# 140    Janoris Jenkins       CB   Power Up         NYG,LAR         2
# 141  Damon Harrison Sr       DT   Power Up         NYG,NYJ         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/179/thumbs/17994552009.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# SF
#                 Name Position       Type     String / Filter  numTeams
# 85     Deion Sanders       CB  Legend PU  ATL,SF,DAL,WAS,BAL         5
# 91       Larry Allen       RG  Legend PU              DAL,SF         2
# 98      Kevin Greene     LOLB  Legend PU      LAR,PIT,CAR,SF         4
# 100       Randy Moss       WR  Legend PU   MIN,OAK,NE,TEN,SF         5
# 114      Rod Woodson       CB        HoF      PIT,SF,BAL,OAK         4
# 116       Jerry Rice       WR    Captain          SF,OAK,SEA         3
# 117     Terell Owens       WR        HoF  SF,PHI,DAL,BUF,CIN         5
# 119      Steve Young       QB  Legend PU               TB,SF         2
# 171    Kyle Juszczyk       FB   Power Up              SF,BAL         2
# 172  Richard Sherman       CB   Power Up              SF,SEA         2
# 182   Delanie Walker       TE   Power Up              TEN,SF         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/169/thumbs/364.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# CHI
#                 Name Position      Type String / Filter  numTeams
# 17        Greg Olsen       TE  Power Up         CAR,CHI         2
# 18       Adrian Amos       SS  Power Up             CHI         1
# 19     Jordan Howard       HB  Power Up             CHI         1
# 20   Danny Trevathan      MLB  Power Up         CHI,DEN         2
# 75       Josh Sitton       LG  Power Up      MIA,GB,CHI         3
# 89    Brian Urlacher      MLB       HoF             CHI         1
# 145      Khalil Mack       LE  Power Up         CHI,OAK         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/165/thumbs/406.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# DAL
#                  Name Position       Type     String / Filter  numTeams
# 26     Ezekiel Elliot       HB   Power Up                 DAL         1
# 27   Travis Frederick        C   Power Up                 DAL         1
# 28           Sean Lee     ROLB   Power Up                 DAL         1
# 29        Zack Martin       RG   Power Up                 DAL         1
# 30        Tyron Smith       LT   Power Up                 DAL         1
# 85      Deion Sanders       CB  Legend PU  ATL,SF,DAL,WAS,BAL         5
# 90      DeMarcus Ware     LOLB  Legend PU             DAL,DEN         2
# 91        Larry Allen       RG  Legend PU              DAL,SF         2
# 117      Terell Owens       WR        HoF  SF,PHI,DAL,BUF,CIN         5

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/150/thumbs/15073062018.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# MIA
#                Name Position      Type String / Filter  numTeams
# 25    Jarvis Landry       WR  Power Up         CLE,MIA         2
# 72    Ndamukong Suh       DT  Power Up     LAR,DET,MIA         3
# 74     Reshad Jones       SS  Power Up             MIA         1
# 75      Josh Sitton       LG  Power Up      MIA,GB,CHI         3
# 99       Dan Marino       QB       HoF             MIA         1
# 104  Ricky Williams       HB    Master      NO,MIA,BAL         3
# 177    Brent Grimes       CB  Power Up      TB,ATL,MIA         3

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/161/thumbs/9ebzja2zfeigaziee8y605aqp.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# DEN
#                  Name Position       Type String / Filter  numTeams
# 20    Danny Trevathan      MLB   Power Up         CHI,DEN         2
# 31    Chris Harris Jr       CB   Power Up             DEN         1
# 32         Von Miller     LOLB   Power Up             DEN         1
# 33   Demaryius Thomas       WR   Power Up             DEN         1
# 90      DeMarcus Ware     LOLB  Legend PU         DAL,DEN         2
# 92      Terrell Davis       HB        HoF             DEN         1
# 93      Steve Atwater       SS     Legend             DEN         1
# 94     Shannon Sharpe       TE    Captain         DEN,BAL         2
# 112     Brian Dawkins       SS  Legend PU         PHI,DEN         2
# 122      Champ Bailey       CB  Legend PU         WAS,DEN         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/157/thumbs/570.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# HOU
#                 Name Position      Type String / Filter  numTeams
# 43  Jadeveon Clowney     ROLB  Power Up             HOU         1
# 44   DeAndre Hopkins       WR  Power Up             HOU         1
# 45           JJ Watt       LE  Power Up             HOU         1
# 46    Tyrann Mathieu       FS  Power Up         HOU,ARI         2
# 56          AJ Bouye       CB  Power Up         JAX,HOU         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/177/thumbs/kwth8f1cfa2sch5xhjjfaof90.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# ARI
#                 Name Position       Type String / Filter  numTeams
# 0   Larry Fitzgerald       WR   Power Up             ARI         1
# 1      David Johnson       HB   Power Up             ARI         1
# 2   Patrick Peterson       CB   Power Up             ARI         1
# 46    Tyrann Mathieu       FS   Power Up         HOU,ARI         2
# 54   Calais Campbell       LE   Power Up         JAX,ARI         2
# 83   Aeneas Williams       CB  Legend PU         ARI,LAR         2

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/154/thumbs/403.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# CIN
#               Name Position       Type            String / Filter  numTeams
# 21     Geno Atkins       DT   Power Up                        CIN         1
# 22        AJ Green       WR   Power Up                        CIN         1
# 24   Kevin Zeitler       RG   Power Up                    CLE,CIN         2
# 105   Lorenzo Neal       FB  Legend PU  NO,NYJ,TB,TEN,CIN,LAC,BAL         7
# 117   Terell Owens       WR        HoF         SF,PHI,DAL,BUF,CIN         5

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/170/thumbs/17013982017.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# DET
#                 Name Position       Type String / Filter  numTeams
# 34    Darius Slay Jr       CB   Power Up             DET         1
# 35  Matthew Stafford       QB   Power Up             DET         1
# 36   Golden Tate III       WR   Power Up         DET,SEA         2
# 72     Ndamukong Suh       DT   Power Up     LAR,DET,MIA         3
# 95     Barry Sanders       HB  Legend PU             DET         1

# %% [markdown]
# ![Image](http://content.sportslogos.net/logos/7/158/thumbs/593.gif)

# %%
i+=1
print(team_abbrevs[i])
team_list[i]
# Out:
# IND
#                Name Position       Type    String / Filter  numTeams
# 47        TY Hilton       WR   Power Up                IND         1
# 48      Andrew Luck       QB   Power Up                IND         1
# 49    Jabaal Sheard       RE   Power Up         IND,CLE,NE         3
# 96    Ted Hendricks     LOLB  Legend PU         IND,GB,OAK         3
# 149  Rashaan Melvin       CB   Power Up  OAK,TB,BAL,NE,IND         5
