# %% [markdown]
# # MUT Scraper
# ### A short tutorial for the MUTScraper module
# #### Matt Johnson. April 27, 2019
#
# -------------
#
# Available Position Options:
# - WR
# - RB
# - QB
# - FB
# - TE
# - OL (LT, LG, C, RG, RT)
# - DB (SS, FS, CB)
# - LB (ROLB, MLB, LOLB)
# - DL (RE, DT, LE)
# - ST (K, P)

# %%
# Import Libraries
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
import plotly as py
import plotly.plotly as py
import plotly.graph_objs as go
from ipywidgets import interactive, HBox, VBox, widgets, interact
from MUTScraper import Player, PlayerHandler

# %% [markdown]
# #### Input position, minimum overall, and date:
# Click the link and get the number of pages (TODO: this is not great, fix).
#
# Here we have chosen to look at Defensive Line (DL) players:

# %%
ph = PlayerHandler(position='WR', min_ovr=95, date='apr27')
# Out:
# Retrieve the number of pages...
# https://www.muthead.com/19/players?filter-market=3&filter-ovr-min=95&filter-position=8&page=1

# %% [markdown]
# #### Start Scraping
# Calling handle_players(pages=numberOfPages) starts the scraping process:

# %%
ph.handle_players(pages=3)
# Out:
#  75 player links gathered.

# %% [markdown]
# #### Data
# We now have the defensive attributes and traits for the players.<br>
# Here is the DataFrame holding the player data:

# %%
pdf = ph.player_df
pdf.head()
# Out:
#                   ACC  AGI  AWR  BCV  BTK  CAR  CIT  CTH  DRR  ELU ...   \
# Odell Beckham Jr   97   99   97   96   91   75   96   96   97   96 ...
# Antonio Brown      96   99   99   97   88   79   98   99   96   96 ...
# Stefon Diggs       98   98   98   93   90   78   95   98   98   92 ...
# Julian Edelman     98   98   99   98   90   79   99   99   91   94 ...
# Keyshawn Johnson   95   94   97   95   86   79   98   98   94   79 ...
#
#                   Makes Possession Catche  Makes RAC Catche  \
# Odell Beckham Jr                       No               Yes
# Antonio Brown                         Yes               Yes
# Stefon Diggs                           No               Yes
# Julian Edelman                        Yes               Yes
# Keyshawn Johnson                      Yes               Yes
#
#                   Makes Sideline Catche        Penalty                HtWt  \
# Odell Beckham Jr                    Yes  Undisciplined  Ht: 5' 11" Wt: 198
# Antonio Brown                       Yes  Undisciplined  Ht: 5' 10" Wt: 181
# Stefon Diggs                        Yes          Norma   Ht: 6' 0" Wt: 191
# Julian Edelman                      Yes    Disciplined  Ht: 5' 10" Wt: 200
# Keyshawn Johnson                    Yes          Norma   Ht: 6' 4" Wt: 211
#
#                   OVR  Position                  Team  Ht   Wt
# Odell Beckham Jr   99        WR      Cleveland Browns  71  198
# Antonio Brown      99        WR       Oakland Raiders  70  181
# Stefon Diggs       99        WR     Minnesota Vikings  72  191
# Julian Edelman     99        WR  New England Patriots  70  200
# Keyshawn Johnson   99        WR         New York Jets  76  211
#
# [5 rows x 42 columns]

# %% [markdown]
# #### Variables

# %%
print(pdf.columns)
# Out:
# Index([ACC, AGI, AWR, BCV, BTK, CAR, CIT, CTH, DRR, ELU, IBL, JKM, JMP, LBK,
#        MRR, RBF, RBK, RBP, RLS, SFA, SPC, SPD, SPM, SRR, STR, TRK, 'Clutch',
#        'Covers Ball', 'Drops Open Passe', 'Fights for Extra Yard',
#        'High Motor', 'Makes Aggressive Catche', 'Makes Possession Catche',
#        'Makes RAC Catche', 'Makes Sideline Catche', 'Penalty', 'HtWt', 'OVR',
#        'Position', 'Team', 'Ht', 'Wt'],
#       dtype='object')

# %%
pdf.shape
# Out:
# (75, 42)

# %%
pdf.dtypes
# Out:
# ACC                         int64
# AGI                         int64
# AWR                         int64
# BCV                         int64
# BTK                         int64
# CAR                         int64
# CIT                         int64
# CTH                         int64
# DRR                         int64
# ELU                         int64
# IBL                         int64
# JKM                         int64
# JMP                         int64
# LBK                         int64
# MRR                         int64
# RBF                         int64
# RBK                         int64
# RBP                         int64
# RLS                         int64
# SFA                         int64
# SPC                         int64
# SPD                         int64
# SPM                         int64
# SRR                         int64
# STR                         int64
# TRK                         int64
# Clutch                     object
# Covers Ball                object
# Drops Open Passe           object
# Fights for Extra Yard      object
# High Motor                 object
# Makes Aggressive Catche    object
# Makes Possession Catche    object
# Makes RAC Catche           object
# Makes Sideline Catche      object
# Penalty                    object
# HtWt                       object
# OVR                         int64
# Position                   object
# Team                       object
# Ht                          int64
# Wt                          int64
# dtype: object

# %%
import seaborn as sns

plt.figure(figsize=(14,6))

attribs = ['SPD', 'AGI', 'JMP', 'CIT', 'SPM', 'STR']

for i in range(len(attribs)):
    plt.subplot(2, 3, i+1)
    sns.distplot(pdf[attribs[i]]);
plt.tight_layout();

# %%
heavy = pdf[ pdf['Wt'] >= 300]
lighter = pdf[ pdf['Wt'] < 300]

fast = pdf[ pdf['SPD'] >= 80]
medium = pdf[ (pdf['SPD'] >= 70) & (pdf['SPD'] < 80)]
slow = pdf[ pdf['SPD'] < 70]

# %% [markdown]
# Grouping players by position:

# %%
position_groups = pdf.groupby('Position')

df_dict = {}

for name, group in position_groups:
    df_dict.update({name: group})

# %% [markdown]
# Method for filtering dataframe by an attributes rating:

# %%
def attribute_restriction(dat, attrib, rating):
    df = dat.copy()
    df = df[ df[attrib] >= rating]
    return df

# %% [markdown]
# ### Visualization with Plotly

# %%
#pdf2 = attribute_restriction(pdf, 'AGI', 87)
#pdf2 = attribute_restriction(pdf2, 'SPD', 85)

#df = pdf

color_map = {'WR': 'rgb(230,0,230)'}

attrib_list = ['SPD', 'AGI', 'JMP', 'CIT', 'SPM', 'STR', 'Ht', 'RBK', 'SPC']


def get_trace(pos, df0):

    trace = go.Splom(dimensions=[dict(label=attrib, values=df0[attrib]) for attrib in attrib_list],
                text=df0.index.values,
                name=pos,
                marker=dict(size=5,
                            showscale=False,
                            line=dict(width=0.5,
                                      color=color_map.get(pos)))
                )
    return trace

# %%
# Trace
traces = []

for pos in ['WR']:
    traces.append( get_trace(pos, df_dict.get(pos)))

# Axis
axis = dict(showline=True,
          zeroline=False,
          gridcolor='#fff',
          ticklen=4)

layout = go.Layout(
    title='MUT19 WRs (95+ OVR)',
    dragmode='select',
    width=1000,
    height=800,
    autosize=False,
    hovermode='closest',
    plot_bgcolor='rgba(240,240,240, 0.95)',
    xaxis1=dict(axis), xaxis2=dict(axis), xaxis3=dict(axis), xaxis4=dict(axis),
    xaxis5=dict(axis), xaxis6=dict(axis), xaxis7=dict(axis), xaxis8=dict(axis),
    yaxis1=dict(axis), yaxis2=dict(axis), yaxis3=dict(axis), yaxis4=dict(axis),
    yaxis5=dict(axis), yaxis6=dict(axis), yaxis7=dict(axis), yaxis8=dict(axis)
)

for trace in traces:
    trace['diagonal'].update(visible=False)
    trace['showupperhalf']=False

fig = dict(data=traces, layout=layout)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perronfrobenius/138.embed" height="800px" width="1000px"></iframe>

# %% [markdown]
# ### Correlation between Variables:
# We can see a correlation of 1 between PRC and AWR and -0.8 between SPD and Wt.

# %%
plt.subplots(figsize=(15,8))
sns.heatmap(pdf.corr(), linewidths=.5, annot=True);
plt.tight_layout();

# %%
#pdf[ (pdf['Strips Ball'] == 'Yes') & (pdf['Big Hitter'] == 'Yes')]

# %%
print('Clutch:')
set(pdf[ pdf['Clutch'] == 'Yes'].index)
# Out:
# Clutch:
# {'A.J. Green',
#  'Andre Reed',
#  'Antonio Brown',
#  'Calvin Johnson',
#  'Cris Carter',
#  'DeAndre Hopkins',
#  'Golden Tate III',
#  'Julian Edelman',
#  'Julio Jones',
#  'Keenan Allen',
#  'Larry Fitzgerald',
#  'Michael Thomas',
#  'Odell Beckham Jr',
#  'Randy Moss',
#  'Stefon Diggs',
#  'Steve Smith Sr',
#  'Tim Brown'}

# %%
pdf.corr()
# Out:
#           ACC       AGI       AWR       BCV       BTK       CAR       CIT  \
# ACC  1.000000  0.483522  0.392131  0.341792  0.378384 -0.071548  0.167302
# AGI  0.483522  1.000000  0.296619  0.658762  0.710110 -0.125728  0.094738
# AWR  0.392131  0.296619  1.000000  0.532134  0.044010 -0.025014  0.540398
# BCV  0.341792  0.658762  0.532134  1.000000  0.516449 -0.000954  0.318638
# BTK  0.378384  0.710110  0.044010  0.516449  1.000000  0.215225  0.039719
# CAR -0.071548 -0.125728 -0.025014 -0.000954  0.215225  1.000000  0.204969
# CIT  0.167302  0.094738  0.540398  0.318638  0.039719  0.204969  1.000000
# CTH  0.435807  0.309550  0.733314  0.420449 -0.021745 -0.085283  0.548587
# DRR  0.317791  0.158212  0.034429  0.079522  0.146255 -0.065258 -0.070071
# ELU  0.464040  0.777215  0.083886  0.536195  0.815057 -0.007110 -0.099010
# IBL -0.225904 -0.155553  0.058843  0.038023 -0.244494  0.115232  0.238886
# JKM  0.583744  0.655337  0.271982  0.552778  0.748553 -0.053472  0.052159
# JMP -0.094477 -0.261405  0.045421 -0.171105 -0.198397  0.153779  0.294487
# LBK -0.273843 -0.365779 -0.092139 -0.256775 -0.266132  0.217801  0.131085
# MRR  0.417714  0.253634  0.685703  0.468170  0.234645  0.131724  0.488964
# RBF -0.180753 -0.105809 -0.019973 -0.084195  0.082944  0.190294  0.342197
