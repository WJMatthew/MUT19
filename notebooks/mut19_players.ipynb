# %% [markdown]
# # Web Scraping MUTHead with BeautifulSoup and Requests
# ## + Plotly
# - ** Matthew Johnson, Oct 6, 2018**

# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt 
import seaborn as sns
import urllib
import pandas as pd
import requests
import warnings; warnings.simplefilter('ignore')  
import time
import re

# %% [markdown]
# **Method to collect stats given a BeautifulSoup item:**

# %%
prefix = 'https://www.muthead.com'

valid_traits = ['Clutch', 'Covers Ball', 'Fights for Extra Yards', 'Makes Aggressive Catches', 'Makes RAC Catches', 
                'Makes Possession Catches', 'Drops Open Passes', 'Makes Sideline Catches', 'High Motor', 'Penalty']

class Player:
    
    def __init__(self, link):
        self.stat_dict = {}
        self.trait_dict = {}
        self.name = ' '.join(link.split('-')[1:])
        self.link = link
        self.full_link = prefix + link #+ f'/upgrades?from={upgrade_number}'
        self.price = '0K'
        self.price_diff = '0%'
        self.traits_correct = 0
        self.ovr = 0
        self.position = '-'
        self.program = '-'
        self.first_name = ''
        self.last_name = ''
        self.team = '-'
        self.height_wt = ''
        self.cap_hit = 0
        
    def get_ratings(self):
        response = requests.get(self.full_link)
        #print(self.full_link)
        soup = BeautifulSoup(response.text, 'html.parser')
        self.soup = soup
        tag_list = []
        stat_list = []
        
        self.get_player_ratings()
        self.get_player_traits()
        #print(stat_list)
        #self.stat_list = stat_l
        #player_ratings_small = [self.read_rating_string(stat.string) for stat in stat_list]
        #print(player_ratings_small)
        #player_traits = [self.get_player_trait(trait) for trait in tag_list[200:300]]
        #print(player_traits)
        
        if len(self.trait_dict.keys()) == 10: self.traits_correct = 1
        self.get_price(self.soup)
        self.set_values(self.soup)
        
    def summary(self):
        print(self.name, ' - ', self.price, ' - ', self.traits_correct)
        
    def get_price(self, soup):
        try:
            self.price = soup.find_all('span', class_='item-price')[1].contents[0]
            self.price_diff = soup.find_all('span', class_='item-price')[1].contents[1]
        except:
            pass
        
    def get_player_ratings(self):
        stat_vals = self.soup.find_all('span', class_='stat') # name also stat-abbreviation
        stat_abbrevs = self.soup.find_all('span', class_='stat-abbreviation')
        [self.stat_dict.update({stat_abbrev.string : stat_val.string}) 
             for stat_abbrev, stat_val in zip(stat_abbrevs, stat_vals)];
    
    # 209-218?
    def get_player_traits(self):
        traits = self.soup.find('ul', class_='player-traits-list').contents

        for trait in traits:
            if trait != '\n': 
                try:
                    trait_key = str(trait).split('>')[2].rstrip('</span')
                    trait_val = str(trait).split('>')[3].rstrip('</li').strip()
                    self.trait_dict.update({trait_key: trait_val})
                except:
                    pass
        
    def set_values(self, soup):
        try: self.ovr = int(soup.find('span', class_='overall').string)
        except: pass
        try: self.pos = soup.find('span', class_='position').string
        except: pass
        try: self.program = soup.find('div', class_='program-name').string
        except: pass
        try: self.first_name = soup.find('span', class_='first-name').string
        except: pass
        try: self.last_name = soup.find('span', class_='last-name').string
        except: pass
        try: self.team = soup.find('span', class_='team').string
        except: pass
        try: self.height_wt = soup.find('span', class_='height-weight').string
        except: pass
        try: self.cap_hit = int(soup.find('span', class_='cap-hit').string)
        except: pass
        
    def get_stats_df(self):
        return pd.DataFrame({self.name : self.stat_dict}).T
    
    def get_traits_df(self):
        return pd.DataFrame({self.name : self.trait_dict}).T

# %% [markdown]
# **Getting player links from the search page filtered with WRs and set to 88+ OVR:**

# %%
# position = 8 <- WR


class PlayerHandler:
    
    def __init__(self):
        self.player_list = []
        self.max = 5
        self.MIN_OVR = 90
        self.player_links = []
    
    def get_player_links(self):
        links = []

        i=0
        while(len(links) < self.max):
            try:
                url = f'https://www.muthead.com/19/players?filter-market=3&filter-ovr-min=90&filter-position=8&page={i}'
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'lxml')
    
                for link in soup.findAll('a', attrs={'href': re.compile("19/players/")}):
                    links.append(link.get('href'))
                i+=1
                
            except:
                print("## error")
                break
        
        self.player_links = [s for s in links if 'prices' not in s]


    def make_player_list(self):

        for player_link in self.player_links:
            p = Player(player_link)
            self.player_list.append(p)
        
        for player in self.player_list:
            player.get_ratings()
            time.sleep(1)
            
    def handle_players(self):
        self.get_player_links()
        self.make_player_list()
        return self.player_list

# %%
links = []
max_players = 5

i=0
while(len(links) < max_players):
            try:
                url = f'https://www.muthead.com/19/players?filter-market=3&filter-ovr-min=90&filter-position=8&page={i}'
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'lxml')
    
                for link in soup.findAll('a', attrs={'href': re.compile("19/players/")}):
                    links.append(link.get('href'))
                i+=1
                
            except:
                print("## error")
                break
        
player_links = [s for s in links if 'prices' not in s]

# %%
player_list = []

for player_link in player_links[:1]:
            p = Player(player_link)
            player_list.append(p)

# %%
for player in player_list:
            player.get_ratings()
            time.sleep(1)

# %%
player1 = player_list[0]
player1.program
# Out:
# 'MUT Monsters'

# %%
player1.trait_dict
# Out:
# {'Clutch': 'Yes',
#  'Covers Ball': 'Brace for All Hits',
#  'Drops Open Passe': 'No',
#  'Fights for Extra Yard': 'Yes',
#  'High Motor': 'Yes',
#  'Makes Aggressive Catche': 'Yes',
#  'Makes Possession Catche': 'Yes',
#  'Makes RAC Catche': 'Yes',
#  'Makes Sideline Catche': 'Yes',
#  'Penalty': 'Disciplined'}

# %%
 # 3, 5, 7, ... 

a = player1.soup.find('ul', class_='player-traits-list').contents
a

for _ in a:
    if _ != '\n': 
        try:
            trait_key = str(_).split('>')[2].rstrip('</span')
            trait_val = str(_).split('>')[3].rstrip('</li').strip()
            print(trait_key, ':', trait_val)
        except:
            pass
# Out:
# Clutch : Yes
# Covers Ball : Brace for All Hits
# Fights for Extra Yard : Yes
# Makes Aggressive Catche : Yes
# Makes RAC Catche : Yes
# Makes Possession Catche : Yes
# Drops Open Passe : No
# Makes Sideline Catche : Yes
# High Motor : Yes
# Penalty : Disciplined

# %%
temp = str(player1.soup.find('ul', class_='player-traits-list').contents[1])
trait_key = str(temp).split('>')[2].rstrip('</span')
trait_val = str(temp).split('>')[3].rstrip('</li').strip()
# Out:
# 'Yes'

# %%
temp = player1.soup.find('ul', class_='player-traits-list').contents[19]

# %%
trait_key = str(temp).split('>')[2].rstrip('</span')
trait_val = str(temp).split('>')[3].rstrip('</li').strip()
print(trait_key, ':', trait_val)
# Out:
# Penalty : Disciplined

# %%
<div class="player-traits">
<h5>Player Traits</h5>
<ul class="player-traits-list">
<li><span>Clutch</span> Yes</li>
<li><span>Covers Ball</span> Brace for All Hits</li>
<li><span>Fights for Extra Yards</span> Yes</li>
<li><span>Makes Aggressive Catches</span> Yes</li>
<li><span>Makes RAC Catches</span> Yes</li>
<li><span>Makes Possession Catches</span> Yes</li>
<li><span>Drops Open Passes</span> No</li>
<li><span>Makes Sideline Catches</span> Yes</li>
<li><span>High Motor</span> Yes</li>
<li><span>Penalty</span> Disciplined</li>
</ul>
</div>

# %%
ph = PlayerHandler()

wrs = ph.handle_players()

# %%
wr_stat_list = []
wr_trait_list = []

for wr in wrs:
    wr.summary()
    wr_stat_list.append(wr.get_stats_df())
    wr_trait_list.append(wr.get_traits_df())

wr_stats = pd.concat(wr_stat_list)
wr_traits = pd.concat(wr_trait_list)

for _ in wr_stats.columns:
    wr_stats[_] = wr_stats[_].astype(int)
    
all_data = pd.concat([wr_stats, wr_traits], axis=1)

all_data.to_csv('mut_wrs_90plus_nov17.csv')
# Out:
# calvin johnson  -  690K   -  1
# andre reed  -  782K   -  1
# julian edelman  -  605K   -  1
# larry fitzgerald  -  660K   -  1
# jarvis landry  -  625K   -  1
# steve smith sr  -  350K   -  1
# adam thielen  -  436K   -  1
# odell beckham jr  -  802K   -  1
# antonio brown  -  335K   -  1
# deandre hopkins  -  321K   -  1
# alshon jeffery  -  321K   -  1
# herman moore  -  600K   -  1
# steve smith sr  -  680K   -  1
# keenan allen  -  195K   -  1
# tim brown  -  145K   -  1
# mike evans  -  626K   -  1
# t y hilton  -  578K   -  1
# julio jones  -  223K   -  1
# randy moss  -  270K   -  1
# jordy nelson  -  160K   -  1
# steve smith sr  -  150K   -  1
# golden tate iii  -  186K   -  1
# michael thomas  -  240K   -  1
# kelvin benjamin  -  142K   -  1
# brandin cooks  -  227K   -  1

# %%
# Out:
#                   ACC  AGI  AWR  BCV  BTK  CAR  CIT  CTH  DRR  ELU  \
# calvin johnson     92   93   89   87   85   80   92   90   93   85
# andre reed         91   93   93   88   83   76   92   93   90   87
# julian edelman     91   91   95   91   83   72   94   92   82   87
# larry fitzgerald   88   85   95   91   71   71   93   95   85   71
# jarvis landry      89   90   93   91   84   73   90   95   85   86
# steve smith sr     92   91   91   91   88   71   92   91   90   90
# adam thielen       91   91   92   87   78   68   89   93   88   77
# odell beckham jr   90   93   92   90   85   69   89   88   90   90
# antonio brown      89   94   92   92   82   73   91   92   88   90
# deandre hopkins    89   88   92   88   75   76   95   92   86   75
# alshon jeffery     87   86   93   84   69   77   93   91   90   62
# herman moore       89   91   91   84   82   75   89   91   91   80
# steve smith sr     91   90   90   90   87   70   91   90   89   89
# keenan allen       88   88   94   89   72   71   89   94   86   69
# tim brown          90   91   91   89   81   84   88   89   82   88
# mike evans         88   83   93   86   74   74   91   87   88   69
# t y hilton         90   93   89   92   87   67   86   92   91   93
# julio jones        86   90   88   90   81   73   90   90   85   83
# randy moss         89   87   90   85   71   68   88   91   91   78
# jordy nelson       90   87   91   91   75   75   89   93   83   72
# steve smith sr     90   88   88   89   86   69   90   90   89   88
# golden tate iii    88   93   92   90   85   75   89   90   80   91
# michael thomas     90   89   92   82   77   74   87   91   86   75
# kelvin benjamin    86   85   89   83   69   77   92   89   81   66
# brandin cooks      89   93   87   89   80   71   85   91   87   85
#
#                       ...        Clutch            Covers Ball  \
# calvin johnson        ...           Yes     Brace for All Hits
# andre reed            ...           Yes  Brace vs. Big Hitters
# julian edelman        ...           Yes     Brace for All Hits
# larry fitzgerald      ...           Yes     Brace for All Hits
# jarvis landry         ...            No     Brace for All Hits
# steve smith sr        ...           Yes     Brace for All Hits
# adam thielen          ...            No     Brace for All Hits
# odell beckham jr      ...           Yes     Brace for All Hits
# antonio brown         ...           Yes     Brace for All Hits
# deandre hopkins       ...           Yes     Brace for All Hits
# alshon jeffery        ...            No     Brace for All Hits
# herman moore          ...           Yes     Brace for All Hits
# steve smith sr        ...           Yes     Brace for All Hits
# keenan allen          ...           Yes     Brace for All Hits
# tim brown             ...           Yes  Brace vs. Big Hitters
# mike evans            ...            No     Brace for All Hits
# t y hilton            ...            No     Brace for All Hits
# julio jones           ...           Yes     Brace for All Hits
# randy moss            ...           Yes                 Always
# jordy nelson          ...           Yes     Brace for All Hits
# steve smith sr        ...           Yes     Brace for All Hits
# golden tate iii       ...           Yes     Brace for All Hits
# michael thomas        ...           Yes     Brace for All Hits
# kelvin benjamin       ...            No     Brace for All Hits
# brandin cooks         ...            No     Brace for All Hits
#
#                   Drops Open Passe  Fights for Extra Yard  High Motor  \
# calvin johnson                  No                    Yes         Yes
# andre reed                      No                    Yes         Yes
# julian edelman                  No                    Yes         Yes
# larry fitzgerald                No                    Yes         Yes
# jarvis landry                   No                    Yes         Yes
# steve smith sr                  No                    Yes         Yes
# adam thielen                    No                     No         Yes
# odell beckham jr                No                    Yes          No
# antonio brown                   No                    Yes         Yes
# deandre hopkins                 No                    Yes         Yes
# alshon jeffery                  No                    Yes          No
# herman moore                    No                     No         Yes
# steve smith sr                  No                    Yes         Yes
# keenan allen                    No                    Yes         Yes
# tim brown                       No                    Yes         Yes
# mike evans                      No                    Yes          No
# t y hilton                      No                     No         Yes
# julio jones                     No                    Yes         Yes
# randy moss                      No                     No          No
# jordy nelson                    No                    Yes         Yes
# steve smith sr                  No                    Yes         Yes
# golden tate iii                 No                    Yes         Yes
# michael thomas                  No                    Yes         Yes
# kelvin benjamin                 No                    Yes          No
# brandin cooks                   No                     No         Yes
#
#                   Makes Aggressive Catche  Makes Possession Catche  \
# calvin johnson                        Yes                      Yes
# andre reed                             No                      Yes
# julian edelman                         No                      Yes
# larry fitzgerald                      Yes                      Yes
# jarvis landry                         Yes                       No
# steve smith sr                        Yes                       No
# adam thielen                          Yes                      Yes
# odell beckham jr                      Yes                       No
# antonio brown                         Yes                      Yes
# deandre hopkins                       Yes                      Yes
# alshon jeffery                        Yes                       No
# herman moore                          Yes                      Yes
# steve smith sr                        Yes                       No
# keenan allen                          Yes                       No
# tim brown                             Yes                      Yes
# mike evans                            Yes                      Yes
# t y hilton                             No                      Yes
# julio jones                           Yes                       No
# randy moss                            Yes                      Yes
# jordy nelson                          Yes                      Yes
# steve smith sr                        Yes                       No
# golden tate iii                        No                      Yes
# michael thomas                        Yes                      Yes
# kelvin benjamin                       Yes                      Yes
# brandin cooks                          No                       No
#
#                   Makes RAC Catche  Makes Sideline Catche        Penalty
# calvin johnson                 Yes                    Yes    Disciplined
# andre reed                     Yes                    Yes          Norma
# julian edelman                 Yes                    Yes    Disciplined
# larry fitzgerald               Yes                    Yes          Norma
# jarvis landry                  Yes                    Yes          Norma
# steve smith sr                 Yes                    Yes          Norma
# adam thielen                   Yes                    Yes          Norma
# odell beckham jr               Yes                    Yes  Undisciplined
# antonio brown                  Yes                    Yes  Undisciplined
# deandre hopkins                Yes                    Yes  Undisciplined
# alshon jeffery                 Yes                    Yes  Undisciplined
# herman moore                   Yes                    Yes          Norma
# steve smith sr                 Yes                    Yes          Norma
# keenan allen                   Yes                    Yes          Norma
# tim brown                      Yes                    Yes          Norma
# mike evans                      No                    Yes          Norma
# t y hilton                     Yes                    Yes          Norma
# julio jones                    Yes                    Yes    Disciplined
# randy moss                     Yes                    Yes          Norma
# jordy nelson                   Yes                    Yes    Disciplined
# steve smith sr                 Yes                    Yes          Norma
# golden tate iii                Yes                    Yes          Norma
# michael thomas                 Yes                    Yes          Norma
# kelvin benjamin                 No                    Yes          Norma
# brandin cooks                  Yes                    Yes          Norma
#
# [25 rows x 36 columns]

# %%
#temp = soup.find_all('div', class_='price-container')[1].contents[3]
soup.find_all('span', class_='item-price')[1].contents[0]
# Out:
# '104K '

# %%
ph.player_list[0].get_traits_df()
# Out:
# Empty DataFrame
# Columns: []
# Index: [calvin johnson]

# %%
for i in range(len(wrs)):
    print(i, ':', wrs[i].stat_dict.keys())
    print()
# Out:
# 0 : dict_keys([])
#
# 1 : dict_keys([])
#
# 2 : dict_keys([])
#
# 3 : dict_keys([])
#
# 4 : dict_keys([])
#
# 5 : dict_keys([])
#
# 6 : dict_keys([])
#
# 7 : dict_keys([])
#
# 8 : dict_keys([])
#
# 9 : dict_keys([])
#
# 10 : dict_keys([])
#
# 11 : dict_keys([])
#
# 12 : dict_keys([])
#
# 13 : dict_keys([])
#
# 14 : dict_keys([])
#
# 15 : dict_keys([])
#
# 16 : dict_keys([])
#
# 17 : dict_keys([])
#
# 18 : dict_keys([])
#
# 19 : dict_keys([])
#
# 20 : dict_keys([])
#
# 21 : dict_keys([])
#
# 22 : dict_keys([])
#
# 23 : dict_keys([])
#
# 24 : dict_keys([])

# %%
<span class="overall">90</span>
<span class="position">WR</span>

<div class="right-bar">
<ul class="chemistries">
<li class="tip" data-count="1" title="Cincinnati Bengals | Boosts all Bengals players."><img src="https://media-touchdown.cursecdn.com/avatars/thumbnails/184/658/24/24/avatar.png"/></li>
</ul>
</div>
<img class="program-icon flashbacks" src="https://media-touchdown.cursecdn.com/avatars/thumbnails/183/512/32/32/avatar.png"/>


<div class="name">
<span class="first-and-last-name">A.J. Green</span>

<div class="program-name">Flashbacks</div>

<span class="cap-hit">40</span>

<div class="name-stats">
<span class="first-name">A.J.</span>
<span class="last-name">Green</span>
<span class="team">Cincinnati Bengals</span>
<span class="height-weight">Ht: 6' 4" Wt: 210</span>

# %%
ovr = int(soup.find('span', class_='overall').string)
pos = soup.find('span', class_='position').string
program = soup.find('div', class_='program-name').string
firstname = soup.find('span', class_='first-name').string
lastname = soup.find('span', class_='last-name').string
team = soup.find('span', class_='team').string
htwt = soup.find('span', class_='height-weight').string
caphit = int(soup.find('span', class_='cap-hit').string)

# %%
[int(s) for s in str.split() if s.isdigit()]
# Out:
# []

# %%
ovr_str
# Out:
# '90'

# %%
for t in valid_traits:
    print(len(t))
# Out:
# 6
# 11
# 22
# 24
# 17
# 24
# 17
# 22
# 10
# 7

# %%
response = requests.get(p_list[0].full_link)
soup = BeautifulSoup(response.text, 'html.parser')
tag_list = []
stat_list = []
for sec_tag in soup.find_all('section', {'class':'player-details'}):
    for span_tag in sec_tag.find_all('ul', {'class':'player-details-stats'}):
        for i, li_tag in enumerate(sec_tag.find_all('li')):
            for j, stat in enumerate(li_tag.find_all('li')):
                print(i, '-', j, stat)
                stat_list.append(stat)
            tag_list.append(str(li_tag))
# Out:
# 0 - 0 <li data-stat-abbreviation="SPD"><span class="stat stat-green-dark" data-stat-value="85">85</span> <span class="stat-abbreviation">SPD</span></li>
# 0 - 1 <li data-stat-abbreviation="ACC"><span class="stat stat-green-dark" data-stat-value="85">85</span> <span class="stat-abbreviation">ACC</span></li>
# 0 - 2 <li data-stat-abbreviation="AGI"><span class="stat stat-green-dark" data-stat-value="89">89</span> <span class="stat-abbreviation">AGI</span></li>
# 0 - 3 <li data-stat-abbreviation="STR"><span class="stat stat-orange-dark" data-stat-value="67">67</span> <span class="stat-abbreviation">STR</span></li>
# 0 - 4 <li data-stat-abbreviation="JMP"><span class="stat stat-green-light" data-stat-value="92">92</span> <span class="stat-abbreviation">JMP</span></li>
# 0 - 5 <li data-stat-abbreviation="AWR"><span class="stat stat-green-light" data-stat-value="91">91</span> <span class="stat-abbreviation">AWR</span></li>
# 7 - 0 <li data-stat-abbreviation="CTH"><span class="stat stat-green-dark" data-stat-value="88">88</span> <span class="stat-abbreviation">CTH</span></li>
# 7 - 1 <li data-stat-abbreviation="CIT"><span class="stat stat-green-dark" data-stat-value="89">89</span> <span class="stat-abbreviation">CIT</span></li>
# 7 - 2 <li data-stat-abbreviation="SPC"><span class="stat stat-green-light" data-stat-value="91">91</span> <span class="stat-abbreviation">SPC</span></li>
# 7 - 3 <li data-stat-abbreviation="SRR"><span class="stat stat-green-dark" data-stat-value="88">88</span> <span class="stat-abbreviation">SRR</span></li>
# 7 - 4 <li data-stat-abbreviation="MRR"><span class="stat stat-green-dark" data-stat-value="86">86</span> <span class="stat-abbreviation">MRR</span></li>
# 7 - 5 <li data-stat-abbreviation="DRR"><span class="stat stat-green-dark" data-stat-value="84">84</span> <span class="stat-abbreviation">DRR</span></li>
# 7 - 6 <li data-stat-abbreviation="RLS"><span class="stat stat-green-dark" data-stat-value="87">87</span> <span class="stat-abbreviation">RLS</span></li>
# 15 - 0 <li data-stat-abbreviation="RBK"><span class="stat stat-orange-dark" data-stat-value="61">61</span> <span class="stat-abbreviation">RBK</span></li>
# 15 - 1 <li data-stat-abbreviation="RBP"><span class="stat stat-red" data-stat-value="41">41</span> <span class="stat-abbreviation">RBP</span></li>
# 15 - 2 <li data-stat-abbreviation="RBF"><span class="stat stat-red" data-stat-value="39">39</span> <span class="stat-abbreviation">RBF</span></li>
# 15 - 3 <li data-stat-abbreviation="LBK"><span class="stat stat-red" data-stat-value="28">28</span> <span class="stat-abbreviation">LBK</span></li>
# 15 - 4 <li data-stat-abbreviation="IBL"><span class="stat stat-red" data-stat-value="48">48</span> <span class="stat-abbreviation">IBL</span></li>
# 21 - 0 <li data-stat-abbreviation="TRK"><span class="stat stat-orange-dark" data-stat-value="61">61</span> <span class="stat-abbreviation">TRK</span></li>
# 21 - 1 <li data-stat-abbreviation="ELU"><span class="stat stat-orange-dark" data-stat-value="79">79</span> <span class="stat-abbreviation">ELU</span></li>
# 21 - 2 <li data-stat-abbreviation="BCV"><span class="stat stat-green-dark" data-stat-value="88">88</span> <span class="stat-abbreviation">BCV</span></li>
# 21 - 3 <li data-stat-abbreviation="SFA"><span class="stat stat-orange-dark" data-stat-value="67">67</span> <span class="stat-abbreviation">SFA</span></li>
# 21 - 4 <li data-stat-abbreviation="SPM"><span class="stat stat-green-dark" data-stat-value="80">80</span> <span class="stat-abbreviation">SPM</span></li>
# 21 - 5 <li data-stat-abbreviation="JKM"><span class="stat stat-green-dark" data-stat-value="83">83</span> <span class="stat-abbreviation">JKM</span></li>
# 21 - 6 <li data-stat-abbreviation="CAR"><span class="stat stat-orange-dark" data-stat-value="71">71</span> <span class="stat-abbreviation">CAR</span></li>
# 21 - 7 <li data-stat-abbreviation="BTK"><span class="stat stat-green-dark" data-stat-value="81">81</span> <span class="stat-abbreviation">BTK</span></li>
# 33 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 10/26/2016  </span>
# </li>
# 33 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 3,350  </span>
# </li>
# 33 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 33 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/GuckFoodell">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 33 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=GuckFoodell">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 33 - 5 <li class="honor tip" title="Muthead Honor"><a href="/members/GuckFoodell/honor"></a>2</li>
# 40 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 2/11/2015  </span>
# </li>
# 40 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 3,954  </span>
# </li>
# 40 - 2 <li class="p-comment-statitem gt">GT:
#
#                      <span class="postbit-item gt"> Stoic Martyr  </span>
# </li>
# 40 - 3 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">3.45</span></span>
# </li>
# 40 - 4 <li>Clan: <a href="/clans/100-ironclad">[IRON]</a></li>
# 40 - 5 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Stoic_Martyr">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 40 - 6 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Stoic_Martyr">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 40 - 7 <li class="honor tip" title="Muthead Honor"><a href="/members/Stoic_Martyr/honor"></a>28</li>
# 40 - 8 <li class="username-icon"><img src="https://media-touchdown.cursecdn.com/avatars/42/661/635577875157252572.png"/></li>
# 40 - 9 <li class="supporter-icon"><img src="https://media-touchdown.cursecdn.com/avatars/102/6/635957162703784861.png"/></li>
# 51 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/9/2018  </span>
# </li>
# 51 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 2  </span>
# </li>
# 51 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 51 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/RNELLYC_">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 51 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=RNELLYC_">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 57 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/14/2017  </span>
# </li>
# 57 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 4,812  </span>
# </li>
# 57 - 2 <li class="p-comment-statitem psn-id">PSN ID:
#
#                      <span class="postbit-item psn-id"> Here to help!  </span>
# </li>
# 57 - 3 <li class="p-comment-statitem gt">GT:
#
#                      <span class="postbit-item gt"> Chargers to SB  </span>
# </li>
# 57 - 4 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">1.62</span></span>
# </li>
# 57 - 5 <li>Clan: <a href="/clans/154-be-ultimate-live-limitlessly">[BULL]</a></li>
# 57 - 6 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/primetimedeion21">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 57 - 7 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=primetimedeion21">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 57 - 8 <li class="honor tip" title="Muthead Honor"><a href="/members/primetimedeion21/honor"></a>22</li>
# 57 - 9 <li class="username-icon"><img src="https://media-touchdown.cursecdn.com/avatars/185/118/636688505501150887.png"/></li>
# 68 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/12/2018  </span>
# </li>
# 68 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 1  </span>
# </li>
# 68 - 2 <li class="p-comment-statitem psn-id">PSN ID:
#
#                      <span class="postbit-item psn-id"> Flightman16   </span>
# </li>
# 68 - 3 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 68 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Flightman513">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 68 - 5 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Flightman513">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 75 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 7/27/2018  </span>
# </li>
# 75 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 11  </span>
# </li>
# 75 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 75 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/bigkahuna_burgr">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 75 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=bigkahuna_burgr">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 81 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 10/9/2017  </span>
# </li>
# 81 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 26  </span>
# </li>
# 81 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 81 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Chefpc">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 81 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Chefpc">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 87 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 9/7/2018  </span>
# </li>
# 87 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 6  </span>
# </li>
# 87 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 87 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Cheetas_Nutsack">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 87 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Cheetas_Nutsack">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 93 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 4/27/2016  </span>
# </li>
# 93 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 216  </span>
# </li>
# 93 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 93 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/ny_kia31">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 93 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=ny_kia31">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 99 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 11/30/2014  </span>
# </li>
# 99 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 13,110  </span>
# </li>
# 99 - 2 <li class="p-comment-statitem psn-id">PSN ID:
#
#                      <span class="postbit-item psn-id"> Pm me  </span>
# </li>
# 99 - 3 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">3.39</span></span>
# </li>
# 99 - 4 <li>Clan: <a href="/clans/67-legit-dynasty">[LxD]</a></li>
# 99 - 5 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/nicksr84">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 99 - 6 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=nicksr84">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 99 - 7 <li class="honor tip" title="Muthead Honor"><a href="/members/nicksr84/honor"></a>78</li>
# 99 - 8 <li class="username-icon"><img src="https://media-touchdown.cursecdn.com/avatars/185/118/636688505501150887.png"/></li>
# 99 - 9 <li class="supporter-icon"><img src="https://media-touchdown.cursecdn.com/avatars/101/824/635955821918281890.png"/></li>
# 110 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 9/7/2018  </span>
# </li>
# 110 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 6  </span>
# </li>
# 110 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 110 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Cheetas_Nutsack">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 110 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Cheetas_Nutsack">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 116 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 12/8/2016  </span>
# </li>
# 116 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 35  </span>
# </li>
# 116 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 116 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/enjay3">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 116 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=enjay3">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 122 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/28/2018  </span>
# </li>
# 122 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 70  </span>
# </li>
# 122 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 122 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Slackaveli">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 122 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Slackaveli">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 128 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/28/2018  </span>
# </li>
# 128 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 70  </span>
# </li>
# 128 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 128 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Slackaveli">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 128 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Slackaveli">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 134 - 0 <li class="p-comment-statitem forum-title normal">Evo Member</li>
# 134 - 1 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 9/25/2011  </span>
# </li>
# 134 - 2 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 2,321  </span>
# </li>
# 134 - 3 <li class="p-comment-statitem gt">GT:
#
#                      <span class="postbit-item gt"> DUHQ  </span>
# </li>
# 134 - 4 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">19.09</span></span>
# </li>
# 134 - 5 <li>Clan: <a href="/clans/21-digital-union">[DU]</a></li>
# 134 - 6 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/jman1cin">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 134 - 7 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=jman1cin">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 134 - 8 <li class="honor tip" title="Muthead Honor"><a href="/members/jman1cin/honor"></a>4</li>
# 134 - 9 <li class="username-icon"><img src="https://media-touchdown.cursecdn.com/avatars/21/361/635430233779551320.png"/></li>
# 145 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 2/27/2014  </span>
# </li>
# 145 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 1,779  </span>
# </li>
# 145 - 2 <li class="p-comment-statitem gt">GT:
#
#                      <span class="postbit-item gt"> iXJackAss2423Xi  </span>
# </li>
# 145 - 3 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 145 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/Wes669">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 145 - 5 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=Wes669">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 152 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 5/22/2018  </span>
# </li>
# 152 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 5  </span>
# </li>
# 152 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 152 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/zozozili">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 152 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=zozozili">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 158 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 8/7/2018  </span>
# </li>
# 158 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 13  </span>
# </li>
# 158 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 158 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/NinetiesKid86">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 158 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=NinetiesKid86">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 164 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 9/3/2017  </span>
# </li>
# 164 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 1  </span>
# </li>
# 164 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 164 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/disdobetriflin">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 164 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=disdobetriflin">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 170 - 0 <li class="p-comment-statitem join-date">Join Date:
#
#                      <span class="postbit-item join-date"> 9/21/2017  </span>
# </li>
# 170 - 1 <li class="p-comment-statitem posts">Posts:
#
#                      <span class="postbit-item posts"> 30  </span>
# </li>
# 170 - 2 <li class="p-comment-statitem site-currency">
# <span class="site-currency"><span class="site-currency-name">MHC:</span> <span class="site-currency-amount">0.00</span></span>
# </li>
# 170 - 3 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="View User Profile" data-responsive-label="Profile" href="/members/m0ranwad">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">View User Profile
#      </span>
# </a>
# </li>
# 170 - 4 <li class="user-action b-userAction-item user-action-link-responsive">
# <a class="" data-non-responsive-label="Send Message" data-responsive-label="Message" href="/private-messages/send?recipient=m0ranwad">
# <i class="u-icon u-icon-link-responsive"></i>
# <span class="label">Send Message
#      </span>
# </a>
# </li>
# 180 - 0 <li>
# <input data-boosts='{"STR":1}' id="chem-402-tier-1" type="checkbox"/>
# <label for="chem-402-tier-1">
#                                         Tier 1
#
#                                         <ul class="boosts">
# <li>+1 STR</li>
# </ul>
# </label>
# </li>
# 180 - 1 <li>+1 STR</li>
# 180 - 2 <li>
# <input data-boosts='{"JMP":1}' id="chem-402-tier-2" type="checkbox"/>
# <label for="chem-402-tier-2">
#                                         Tier 2
#
#                                         <ul class="boosts">
# <li>+1 JMP</li>
# </ul>
# </label>
# </li>
# 180 - 3 <li>+1 JMP</li>
# 180 - 4 <li>
# <input data-boosts='{"AGI":1}' id="chem-402-tier-3" type="checkbox"/>
# <label for="chem-402-tier-3">
#                                         Tier 3
#
#                                         <ul class="boosts">
# <li>+1 AGI</li>
# </ul>
# </label>
# </li>
# 180 - 5 <li>+1 AGI</li>
# 180 - 6 <li>
# <input data-boosts='{"ACC":1}' id="chem-402-tier-4" type="checkbox"/>
# <label for="chem-402-tier-4">
#                                         Tier 4
#
#                                         <ul class="boosts">
# <li>+1 ACC</li>
# </ul>
# </label>
# </li>
# 180 - 7 <li>+1 ACC</li>
# 180 - 8 <li>
# <input data-boosts='{"SPD":1}' id="chem-402-tier-5" type="checkbox"/>
# <label for="chem-402-tier-5">
#                                         Tier 5
#
#                                         <ul class="boosts">
# <li>+1 SPD</li>
# </ul>
# </label>
# </li>
# 180 - 9 <li>+1 SPD</li>
# 180 - 10 <li>
# <input data-boosts='{"STR":1,"JMP":1}' id="chem-402-tier-6" type="checkbox"/>
# <label for="chem-402-tier-6">
#                                         Tier 6
#
#                                         <ul class="boosts">
# <li>+1 STR</li>
# <li>+1 JMP</li>
# </ul>
# </label>
# </li>
# 180 - 11 <li>+1 STR</li>
# 180 - 12 <li>+1 JMP</li>
# 180 - 13 <li>
# <input data-boosts='{"AGI":1,"ACC":1}' id="chem-402-tier-7" type="checkbox"/>
# <label for="chem-402-tier-7">
#                                         Tier 7
#
#                                         <ul class="boosts">
# <li>+1 AGI</li>
# <li>+1 ACC</li>
# </ul>
# </label>
# </li>
# 180 - 14 <li>+1 AGI</li>
# 180 - 15 <li>+1 ACC</li>
# 180 - 16 <li>
# <input data-boosts='{"STR":1,"SPD":1}' id="chem-402-tier-8" type="checkbox"/>
# <label for="chem-402-tier-8">
#                                         Tier 8
#
#                                         <ul class="boosts">
# <li>+1 STR</li>
# <li>+1 SPD</li>
# </ul>
# </label>
# </li>
# 180 - 17 <li>+1 STR</li>
# 180 - 18 <li>+1 SPD</li>
# 180 - 19 <li>
# <input data-boosts='{"AGI":1,"JMP":1}' id="chem-402-tier-9" type="checkbox"/>
# <label for="chem-402-tier-9">
#                                         Tier 9
#
#                                         <ul class="boosts">
# <li>+1 AGI</li>
# <li>+1 JMP</li>
# </ul>
# </label>
# </li>
# 180 - 20 <li>+1 AGI</li>
# 180 - 21 <li>+1 JMP</li>
# 180 - 22 <li>
# <input data-boosts='{"SPD":1,"ACC":1}' id="chem-402-tier-10" type="checkbox"/>
# <label for="chem-402-tier-10">
#                                         Tier 10
#
#                                         <ul class="boosts">
# <li>+1 SPD</li>
# <li>+1 ACC</li>
# </ul>
# </label>
# </li>
# 180 - 23 <li>+1 SPD</li>
# 180 - 24 <li>+1 ACC</li>
# 181 - 0 <li>+1 STR</li>
# 183 - 0 <li>+1 JMP</li>
# 185 - 0 <li>+1 AGI</li>
# 187 - 0 <li>+1 ACC</li>
# 189 - 0 <li>+1 SPD</li>
# 191 - 0 <li>+1 STR</li>
# 191 - 1 <li>+1 JMP</li>
# 194 - 0 <li>+1 AGI</li>
# 194 - 1 <li>+1 ACC</li>
# 197 - 0 <li>+1 STR</li>
# 197 - 1 <li>+1 SPD</li>
# 200 - 0 <li>+1 AGI</li>
# 200 - 1 <li>+1 JMP</li>
# 203 - 0 <li>+1 SPD</li>
# 203 - 1 <li>+1 ACC</li>
# 206 - 0 <li><img src="https://media-touchdown.cursecdn.com/avatars/thumbnails/184/658/20/20/avatar.png"/></li>

# %% [markdown]
# soup
# <div class="price-container">
# <span class="console-icon ps4"></span>
# <span class="item-price">105K <span class="price-diff neg">-10.2%</span></span>

# %%
temp = str(soup.find_all('div', class_='price-container')[1]).split('\n')[2]
temp = temp.split('"item-price">')[1]
price = temp.split('<span class="price-diff neg">')[0].strip()
price_diff = temp.split('<span class="price-diff neg">')[1].rstrip('</span></span>')
# Out:
# '-10.2%'

# %%
#upgrade_number = 0
#new_link = link + f'/upgrades?from={upgrade_number}'
new_url = prefix + link + f'/upgrades?from={upgrade_number}'
new_url
# Out:
# 'https://www.muthead.com/19/players/60416-a-j-green/upgrades'

# %%
pd.([ pd.DataFrame({wrs[0].name : wrs[0].stat_dict}).T, pd.DataFrame({wrs[1].name : wrs[1].stat_dict}).T], axis=1)
# Out:
#                    ACC   AGI   AWR   BCV   BTK   CAR   CIT   CTH   DRR   ELU  \
# larry fitzgerald   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# steve smith sr    90.0  88.0  88.0  89.0  86.0  69.0  90.0  90.0  89.0  88.0
#
#                   ...    RBK   RBP   RLS   SFA   SPC   SPD   SPM   SRR   STR  \
# larry fitzgerald  ...   72.0  50.0  93.0  77.0  93.0  83.0  78.0  93.0  77.0
# steve smith sr    ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                    TRK
# larry fitzgerald  73.0
# steve smith sr     NaN
#
# [2 rows x 52 columns]

# %%
x = pd.DataFrame({wrs[0].name : wrs[0].stat_dict}).T
y = pd.DataFrame({wrs[1].name : wrs[1].stat_dict}).T

# %%
# Out:
#                   ACC  AGI  AWR  BCV  BTK  CAR  CIT  CTH  DRR  ELU ...   RBK  \
# steve smith sr     90   88   88   89   86   69   90   90   89   88 ...    60
# larry fitzgerald   88   85   95   91   71   71   93   95   85   71 ...    72
#
#                   RBP  RLS  SFA  SPC  SPD  SPM  SRR  STR  TRK
# steve smith sr     47   82   89   85   88   87   90   69   67
# larry fitzgerald   50   93   77   93   83   78   93   77   73
#
# [2 rows x 26 columns]

# %%
for _ in player_df.columns:
    player_df[_] = player_df[_].astype(int)

# %%
player_df.to_csv('mut19_wrs_oct6.csv')

# %%
player_df.columns
cols = ['CIT', 'CTH', 'SPC', 'DRR', 'MRR', 'SRR', 'SPD', 'STR'] # 'RLS','SPM',

# %% [markdown]
# **RBs:**

# %%
links2 = []

for i in range(1,2):
    rb_url = 'https://www.muthead.com/19/players?filter-ovr-min=88&filter-market=3&&filter-position=2'
    response = requests.get(rb_url)
    soup = BeautifulSoup(response.text, 'lxml')
    
    for link in soup.findAll('a', attrs={'href': re.compile("19/players/")}):
        links2.append(link.get('href'))
        
rb_links = [s for s in links2 if 'prices' not in s]
rb_links = list(set(rb_links))

# %%
def get_rb_stats(soup, name):

    player_dict = {}

    for sec_tag in soup.find_all('section', {'class':'player-details'}):
    
        for span_tag in sec_tag.find_all('ul', {'class':'player-details-stats'}):
    
            for i, li_tag in enumerate(sec_tag.find_all('li')):
            
                #if i not in [0, 7, 15, 21]:
                    x = str(li_tag)
                    x1 = x.lstrip('<li data-stat-abbreviation="')
                    stat = x1[0:3]
                    rating = re.sub('[^0-9]','', str(li_tag))[0:2]
                
                    player_dict.update({stat : rating})
                        
    return pd.DataFrame([player_dict], index=[name])[['ACC', 'AGI', 'BCV', 'BTK', 'CAR',
       'CIT', 'CTH', 'DRR', 'ELU', 'JKM', 'JMP', 'MRR', 'SFA', 'SPC', 'SPD',
       'SPM', 'SRR', 'STR', 'TRK']]

# %%
prefix = 'https://www.muthead.com'

rb_list= []

for link in rb_links:
    new_url = prefix + link + 'upgrades'
    response = requests.get(new_url)
    player_name = ' '.join(link.split('-')[1:])
    soup = BeautifulSoup(response.text, 'html.parser')
    rb_list.append( get_rb_stats(soup, player_name) )
    time.sleep(2)
    
rb_df = pd.concat(rb_list)

# %%
rb_df.head()
# Out:
#                     ACC AGI BCV BTK CAR CIT CTH DRR ELU JKM JMP MRR SFA SPC  \
# christian mccaffrey  91  94  84  82  87  81  83  69  90  91  86  77  74  82
# eddie george         88  84  87  88  88  64  62  52  76  77  73  55  88  50
# barry sanders        90  90  90  88  86  67  68  48  89  89  76  61  75  62
# devonta freeman      88  92  90  87  87  67  70  48  92  93  82  56  74  73
# leonard fournette    89  86  90  87  90  54  66  37  78  85  67  45  88  52
#
#                     SPD SPM SRR STR TRK
# christian mccaffrey  90  92  84  73  61
# eddie george         85  79  64  84  87
# barry sanders        89  89  71  65  69
# devonta freeman      88  93  63  72  86
# leonard fournette    89  87  53  82  93

# %%
for _ in rb_df.columns:
    rb_df[_] = rb_df[_].astype(int)

# %%
rb_df.to_csv('mut19_rbs_oct6.csv')

# %% [markdown]
# ### Learning Plotly

# %%
import plotly as py
py.tools.set_credentials_file(username='xxxxxx',api_key='xxxxxx')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %% [markdown]
# **Plot with hover attributes:**

# %%
# cols = ['CIT', 'CTH', 'SPC', 'DRR', 'MRR', 'SRR', 'SPD', 'STR'] # 'RLS','SPM',

df = player_df

trace1 = go.Splom(dimensions=[dict(label='CIT',
                                 values=df['CIT']),
                            dict(label='CTH',
                                 values=df['CTH']),
                            dict(label='SPC',
                                 values=df['SPC']),
                            dict(label='SPD',
                                 values=df['SPD']),
                            dict(label='DRR',
                                 values=df['DRR']),
                            dict(label='MRR',
                                 values=df['MRR']),
                             dict(label='STR',
                                 values=df['STR'])],
                text=df.index.values,
                marker=dict(size=7,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(230,230,230)'))
                )


axis = dict(showline=True,
          zeroline=False,
          gridcolor='#fff',
          ticklen=4)

layout = go.Layout(
    title='MUT19 Wide Receivers (88+ OVR)',
    dragmode='select',
    width=1000,
    height=1000,
    autosize=False,
    hovermode='closest',
    plot_bgcolor='rgba(240,240,240, 0.95)',
    xaxis1=dict(axis), xaxis2=dict(axis), xaxis3=dict(axis), xaxis4=dict(axis),
    xaxis5=dict(axis), xaxis6=dict(axis), xaxis7=dict(axis), xaxis8=dict(axis),
    yaxis1=dict(axis), yaxis2=dict(axis), yaxis3=dict(axis), yaxis4=dict(axis),
    yaxis5=dict(axis), yaxis6=dict(axis), yaxis7=dict(axis), yaxis8=dict(axis)
)
trace1['diagonal'].update(visible=False)
trace1['showupperhalf']=False
fig1 = dict(data=[trace1], layout=layout)
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perronfrobenius/24.embed" height="1000px" width="1000px"></iframe>

# %%
# cols = ['CIT', 'CTH', 'SPC', 'DRR', 'MRR', 'SRR', 'SPD', 'STR'] # 'RLS','SPM',

df = rb_df

trace1 = go.Splom(dimensions=[dict(label='SPD',
                                 values=df['SPD']),
                            dict(label='SPM',
                                 values=df['SPM']),
                            dict(label='AGI',
                                 values=df['AGI']),
                            dict(label='ELU',
                                 values=df['ELU']),
                            dict(label='TRK',
                                 values=df['TRK']),
                            dict(label='BTK',
                                 values=df['BTK']),
                             dict(label='STR',
                                 values=df['STR'])],
                text=df.index.values,
                marker=dict(size=7,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(230,230,230)'))
                )


axis = dict(showline=True,
          zeroline=False,
          gridcolor='#fff',
          ticklen=4)

layout = go.Layout(
    title='MUT19 Running Backs (88+ OVR)',
    dragmode='select',
    width=1000,
    height=1000,
    autosize=False,
    hovermode='closest',
    plot_bgcolor='rgba(240,240,240, 0.95)',
    xaxis1=dict(axis), xaxis2=dict(axis), xaxis3=dict(axis), xaxis4=dict(axis),
    xaxis5=dict(axis), xaxis6=dict(axis), xaxis7=dict(axis), xaxis8=dict(axis),
    yaxis1=dict(axis), yaxis2=dict(axis), yaxis3=dict(axis), yaxis4=dict(axis),
    yaxis5=dict(axis), yaxis6=dict(axis), yaxis7=dict(axis), yaxis8=dict(axis)
)
trace1['diagonal'].update(visible=False)
trace1['showupperhalf']=False
fig1 = dict(data=[trace1], layout=layout)
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perronfrobenius/26.embed" height="1000px" width="1000px"></iframe>
