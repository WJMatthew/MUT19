# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from MUTScraper import Player, PlayerHandler
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import plotly as py
py.tools.set_credentials_file(username='perronfrobenius',api_key='VdMB7ohq06YbQFEmf5rh')
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
from ipywidgets import interactive, HBox, VBox, widgets, interact

# %%
ph = PlayerHandler(position='OL', min_ovr=86, date='nov18', pages=4)
ph.handle_players()
# Out:
#  100 player links gathered.

# %%
ol_groups = ph.player_df.groupby('Position')

df_dict = {}

for name, group in ol_groups:
    df_dict.update({name: group})

# %%
df = ph.player_df

df0 = df_dict.get('LT')
trace0 = go.Splom(dimensions=[dict(label='RBK', values=df0['RBK']),
                              dict(label='RBF', values=df0['RBF']),
                              dict(label='PBK', values=df0['PBK']),
                              dict(label='PBF', values=df0['PBF']),
                              dict(label='SPD', values=df0['SPD']),
                              dict(label='IBL', values=df0['IBL']),
                              dict(label='STR', values=df0['STR']),
                              dict(label='AGI', values=df0['AGI'])],
                text=df0.index.values,
                name='LT',
                marker=dict(size=6,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(230,0,230)'))
                )

df1 = df_dict.get('LG')
trace1 = go.Splom(dimensions=[dict(label='RBK', values=df1['RBK']),
                              dict(label='RBF', values=df1['RBF']),
                              dict(label='PBK', values=df1['PBK']),
                              dict(label='PBF', values=df1['PBF']),
                              dict(label='SPD', values=df1['SPD']),
                              dict(label='IBL', values=df1['IBL']),
                              dict(label='STR', values=df1['STR']),
                              dict(label='AGI', values=df1['AGI'])],
                text=df1.index.values,
                name='LG',
                marker=dict(size=6,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(230,230,230)'))
                )

df2 = df_dict.get('C')
trace2 = go.Splom(dimensions=[dict(label='RBK', values=df2['RBK']),
                              dict(label='RBF', values=df2['RBF']),
                              dict(label='PBK', values=df2['PBK']),
                              dict(label='PBF', values=df2['PBF']),
                              dict(label='SPD', values=df2['SPD']),
                              dict(label='IBL', values=df2['IBL']),
                              dict(label='STR', values=df2['STR']),
                              dict(label='AGI', values=df2['AGI'])],
                text=df2.index.values,
                name='C',
                marker=dict(size=6,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(20,230,100)'))
                )

df3 = df_dict.get('RG')
trace3 = go.Splom(dimensions=[dict(label='RBK', values=df3['RBK']),
                              dict(label='RBF', values=df3['RBF']),
                              dict(label='PBK', values=df3['PBK']),
                              dict(label='PBF', values=df3['PBF']),
                              dict(label='SPD', values=df3['SPD']),
                              dict(label='IBL', values=df3['IBL']),
                              dict(label='STR', values=df3['STR']),
                              dict(label='AGI', values=df3['AGI'])],
                text=df3.index.values,
                name='RG',
                marker=dict(size=6,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(240,5,30)'))
                )

df4 = df_dict.get('RT')
trace4 = go.Splom(dimensions=[dict(label='RBK', values=df4['RBK']),
                              dict(label='RBF', values=df4['RBF']),
                              dict(label='PBK', values=df4['PBK']),
                              dict(label='PBF', values=df4['PBF']),
                              dict(label='SPD', values=df4['SPD']),
                              dict(label='IBL', values=df4['IBL']),
                              dict(label='STR', values=df4['STR']),
                              dict(label='AGI', values=df4['AGI'])],
                text=df4.index.values,
                name='RT',
                marker=dict(size=6,
                            showscale=False,
                            line=dict(width=0.5,
                                      color='rgb(0,50,240)'))
                )

axis = dict(showline=True,
          zeroline=False,
          gridcolor='#fff',
          ticklen=4)


layout = go.Layout(
    title='MUT19 Offensive Lineman (86+ OVR)',
    dragmode='select',
    width=1000,
    height=800,
    autosize=False,
    hovermode='closest',
    plot_bgcolor='rgba(240,240,240, 0.95)',
    xaxis1=dict(axis), xaxis2=dict(axis), xaxis3=dict(axis), xaxis4=dict(axis),
    xaxis5=dict(axis), xaxis6=dict(axis), xaxis7=dict(axis), xaxis8=dict(axis),
    yaxis1=dict(axis), yaxis2=dict(axis), yaxis3=dict(axis), yaxis4=dict(axis),
    yaxis5=dict(axis), yaxis6=dict(axis), yaxis7=dict(axis), yaxis8=dict(axis)
)
trace0['diagonal'].update(visible=False)
trace0['showupperhalf']=False

trace1['diagonal'].update(visible=False)
trace1['showupperhalf']=False

trace2['diagonal'].update(visible=False)
trace2['showupperhalf']=False

trace3['diagonal'].update(visible=False)
trace3['showupperhalf']=False

trace4['diagonal'].update(visible=False)
trace4['showupperhalf']=False

fig = dict(data=[trace0, trace1, trace2, trace3, trace4], layout=layout)

'''
f = go.FigureWidget(data=fig['data'], layout=fig['layout'])

slider = widgets.IntSlider(
    value=88,
    min=86,
    max=99,
    step=1,
    description='OVR',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)


slider.layout.width = '600px'

def update_range():
    f.data[0].z = np.cos(x * yt * frequency / 10.0) + np.sin(x * yt * frequency / 10.0) * 2


# display the FigureWidget and slider with center justification
vb = VBox((f, interactive(update_range, y=slider)))
vb.layout.align_items = 'center'
vb
'''
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perronfrobenius/88.embed" height="800px" width="1000px"></iframe>

# %%
f.data
# Out:
# (Splom({
#      'diagonal': {'visible': False},
#      'dimensions': [{'label': 'RBK',
#                      'values': array([95., 89., 88., 91., 87., 85., 88., 95., 89., 88., 91., 87., 85., 88.,
#                                       89., 88., 85., 87., 86., 84., 93., 86., 89., 82., 84., 77.])},
#                     {'label': 'RBF',
#                      'values': array([95., 89., 87., 90., 88., 85., 88., 95., 89., 87., 90., 88., 85., 88.,
#                                       88., 85., 85., 86., 83., 85., 84., 86., 86., 82., 84., 77.])},
#                     {'label': 'PBK',
#                      'values': array([92., 93., 92., 92., 95., 94., 89., 92., 93., 92., 92., 95., 94., 89.,
#                                       91., 90., 89., 88., 88., 88., 87., 87., 85., 90., 85., 90.])},
#                     {'label': 'PBF',
#                      'values': array([92., 90., 91., 90., 91., 93., 90., 92., 90., 91., 90., 91., 93., 90.,
#                                       88., 87., 86., 86., 85., 88., 87., 87., 82., 91., 86., 90.])},
#                     {'label': 'SPD',
#                      'values': array([69., 65., 73., 54., 70., 65., 72., 69., 65., 73., 54., 70., 65., 72.,
#                                       52., 60., 61., 50., 58., 66., 65., 57., 63., 57., 68., 61.])},
#                     {'label': 'IBL',
#                      'values': array([90., 87., 91., 89., 81., 84., 78., 90., 87., 91., 89., 81., 84., 78.,
#                                       87., 87., 83., 85., 85., 78., 77., 84., 85., 81., 74., 77.])},
#                     {'label': 'STR',
#                      'values': array([92., 93., 88., 92., 92., 86., 91., 92., 93., 88., 92., 92., 86., 91.,
#                                       90., 90., 89., 88., 88., 88., 87., 89., 84., 82., 87., 82.])},
#                     {'label': 'AGI',
#                      'values': array([62., 62., 71., 55., 74., 65., 67., 62., 62., 71., 55., 74., 65., 67.,
#                                       53., 59., 58., 51., 57., 70., 69., 54., 68., 65., 63., 61.])}],
#      'marker': {'line': {'color': 'rgb(230,0,230)', 'width': 0.5}, 'showscale': False, 'size': 6},
#      'name': 'LT',
#      'showupperhalf': False,
#      'text': array(['Anthony Munoz', 'Jason Peters', 'Taylor Lewan', 'Jonathan Ogden',
#                     'Tyron Smith', 'David Bakhtiari', 'Trent Williams', 'Anthony Munoz',
#                     'Jason Peters', 'Taylor Lewan', 'Jonathan Ogden', 'Tyron Smith',
#                     'David Bakhtiari', 'Trent Williams', 'Jonathan Ogden', 'Willie Roaf',
#                     'Jason Peters', 'Jonathan Ogden', 'Willie Roaf', 'Tyron Smith',
#                     'Tyron Smith', 'Andrew Whitworth', 'Bruce Matthews', 'Russell Okung',
#                     'Trent Williams', 'David Bakhtiari'], dtype=object),
#      'uid': 'a7f380e2-eb50-11e8-a15a-8c85907f6380'
#  }), Splom({
#      'diagonal': {'visible': False},
#      'dimensions': [{'label': 'RBK',
#                      'values': array([92., 94., 88., 92., 94., 88., 90., 84., 91., 90., 93., 84., 88., 87.,
#                                       87., 84.])},
#                     {'label': 'RBF',
#                      'values': array([89., 95., 89., 89., 95., 89., 87., 82., 92., 90., 94., 85., 85., 84.,
#                                       86., 84.])},
#                     {'label': 'PBK',
#                      'values': array([92., 91., 94., 92., 91., 94., 88., 91., 89., 87., 87., 93., 86., 87.,
#                                       86., 89.])},
#                     {'label': 'PBF',
#                      'values': array([89., 89., 93., 89., 89., 93., 86., 91., 88., 84., 85., 91., 84., 84.,
#                                       85., 88.])},
#                     {'label': 'SPD',
#                      'values': array([63., 62., 71., 63., 62., 71., 59., 59., 56., 60., 59., 68., 57., 60.,
#                                       54., 67.])},
#                     {'label': 'IBL',
#                      'values': array([87., 90., 86., 87., 90., 86., 90., 89., 83., 86., 86., 82., 88., 84.,
#                                       84., 85.])},
#                     {'label': 'STR',
#                      'values': array([93., 85., 84., 93., 85., 84., 89., 89., 86., 84., 81., 81., 87., 87.,
#                                       88., 81.])},
#                     {'label': 'AGI',
#                      'values': array([67., 69., 72., 67., 69., 72., 57., 57., 55., 52., 66., 69., 55., 65.,
#                                       52., 47.])}],
#      'marker': {'line': {'color': 'rgb(230,230,230)', 'width': 0.5}, 'showscale': False, 'size': 6},
#      'name': 'LG',
#      'showupperhalf': False,
#      'text': array(['Randall McDaniel', 'Rodger Saffold III', 'Joel Bitonio',
#                     'Randall McDaniel', 'Rodger Saffold III', 'Joel Bitonio',
#                     'Steve Hutchinson', 'Kelechi Osemele', 'Josh Sitton', 'Ron Leary',
#                     'Rodger Saffold III', 'Joel Bitonio', 'Steve Hutchinson',
#                     'Bruce Matthews', 'Larry Allen', 'Quinton Spain'], dtype=object),
#      'uid': 'a7f38228-eb50-11e8-aabc-8c85907f6380'
#  }), Splom({
#      'diagonal': {'visible': False},
#      'dimensions': [{'label': 'RBK',
#                      'values': array([94., 92., 91., 89., 91., 90., 94., 92., 91., 89., 91., 90., 86., 91.,
#                                       92., 88., 81., 85., 83., 88., 87.])},
#                     {'label': 'RBF',
#                      'values': array([91., 92., 89., 91., 92., 90., 91., 92., 89., 91., 92., 90., 85., 92.,
#                                       92., 88., 78., 85., 82., 87., 88.])},
#                     {'label': 'PBK',
#                      'values': array([94., 92., 93., 92., 89., 90., 94., 92., 93., 92., 89., 90., 90., 85.,
#                                       84., 88., 90., 88., 88., 84., 85.])},
#                     {'label': 'PBF',
#                      'values': array([91., 92., 90., 92., 86., 90., 91., 92., 90., 92., 86., 90., 88., 85.,
#                                       86., 88., 88., 85., 89., 86., 82.])},
#                     {'label': 'SPD',
#                      'values': array([64., 60., 62., 62., 51., 58., 64., 60., 62., 62., 51., 58., 58., 58.,
#                                       70., 58., 57., 53., 57., 64., 48.])},
#                     {'label': 'IBL',
#                      'values': array([91., 88., 87., 87., 88., 86., 91., 88., 87., 87., 88., 86., 93., 88.,
#                                       86., 84., 87., 87., 86., 79., 84.])},
#                     {'label': 'STR',
#                      'values': array([91., 90., 89., 90., 88., 88., 91., 90., 89., 90., 88., 88., 87., 87.,
#                                       82., 86., 85., 83., 84., 82., 85.])},
#                     {'label': 'AGI',
#                      'values': array([69., 54., 67., 61., 64., 52., 69., 54., 67., 61., 64., 52., 64., 56.,
#                                       67., 52., 66., 58., 56., 54., 61.])}],
#      'marker': {'line': {'color': 'rgb(20,230,100)', 'width': 0.5}, 'showscale': False, 'size': 6},
#      'name': 'C',
#      'showupperhalf': False,
#      'text': array(['Bruce Matthews', 'Dermontti Dawson', 'Bruce Matthews', 'Kevin Mawae',
#                     'Travis Frederick', 'Dermontti Dawson', 'Bruce Matthews',
#                     'Dermontti Dawson', 'Bruce Matthews', 'Kevin Mawae', 'Travis Frederick',
#                     'Dermontti Dawson', 'Rodney Hudson', 'Alex Mack', 'Jason Kelce',
#                     'Dermontti Dawson', 'Maurkice Pouncey', 'John Sullivan', 'Max Unger',
#                     'David Andrews', 'Travis Frederick'], dtype=object),
#      'uid': 'a7f382d4-eb50-11e8-9901-8c85907f6380'
#  }), Splom({
#      'diagonal': {'visible': False},
#      'dimensions': [{'label': 'RBK',
#                      'values': array([91., 90., 89., 94., 91., 90., 89., 94., 89., 91., 90., 92., 90., 86.,
#                                       92., 88., 90.])},
#                     {'label': 'RBF',
#                      'values': array([90., 89., 90., 94., 90., 89., 90., 94., 89., 89., 88., 92., 89., 88.,
#                                       85., 86., 91.])},
#                     {'label': 'PBK',
#                      'values': array([90., 94., 90., 84., 90., 94., 90., 84., 89., 90., 88., 87., 88., 88.,
#                                       84., 84., 79.])},
#                     {'label': 'PBF',
#                      'values': array([89., 87., 90., 85., 89., 87., 90., 85., 87., 86., 87., 76., 87., 88.,
#                                       84., 84., 80.])},
#                     {'label': 'SPD',
#                      'values': array([56., 56., 66., 68., 56., 56., 66., 68., 71., 63., 55., 69., 56., 62.,
#                                       51., 52., 64.])},
#                     {'label': 'IBL',
#                      'values': array([88., 84., 85., 86., 88., 84., 85., 86., 86., 87., 86., 84., 83., 82.,
#                                       80., 81., 91.])},
#                     {'label': 'STR',
#                      'values': array([92., 90., 89., 89., 92., 90., 89., 89., 82., 86., 90., 83., 87., 85.,
#                                       85., 86., 85.])},
#                     {'label': 'AGI',
#                      'values': array([54., 63., 61., 68., 54., 63., 61., 68., 67., 68., 53., 62., 61., 57.,
#                                       58., 59., 64.])}],
#      'marker': {'line': {'color': 'rgb(240,5,30)', 'width': 0.5}, 'showscale': False, 'size': 6},
#      'name': 'RG',
#      'showupperhalf': False,
#      'text': array(['Larry Allen', 'David DeCastro', 'Zack Martin', 'Brandon Scherff',
#                     'Larry Allen', 'David DeCastro', 'Zack Martin', 'Brandon Scherff',
#                     'Kyle Long', 'Bruce Matthews', 'Larry Allen', 'Shaq Mason',
#                     'Marshal Yanda', 'Zack Martin', 'David DeCastro', 'David DeCastro',
#                     'Brandon Scherff'], dtype=object),
#      'uid': 'a7f38362-eb50-11e8-88b3-8c85907f6380'
#  }), Splom({
#      'diagonal': {'visible': False},
#      'dimensions': [{'label': 'RBK',
#                      'values': array([92., 89., 90., 93., 88., 92., 89., 90., 93., 88., 90., 89., 87., 90.,
#                                       82., 86., 93., 84., 84., 86.])},
#                     {'label': 'RBF',
#                      'values': array([91., 89., 89., 92., 85., 91., 89., 89., 92., 85., 88., 88., 86., 90.,
#                                       82., 86., 93., 83., 84., 85.])},
#                     {'label': 'PBK',
#                      'values': array([92., 92., 90., 86., 92., 92., 92., 90., 86., 92., 92., 88., 90., 88.,
#                                       89., 89., 85., 86., 87., 85.])},
#                     {'label': 'PBF',
#                      'values': array([91., 92., 89., 84., 92., 91., 92., 89., 84., 92., 90., 87., 87., 84.,
#                                       86., 89., 83., 85., 87., 84.])},
#                     {'label': 'SPD',
#                      'values': array([54., 76., 52., 58., 54., 54., 76., 52., 58., 54., 57., 53., 61., 61.,
#                                       59., 66., 55., 50., 72., 53.])},
#                     {'label': 'IBL',
#                      'values': array([93., 84., 91., 80., 85., 93., 84., 91., 80., 85., 79., 90., 82., 80.,
#                                       85., 79., 79., 85., 79., 87.])},
#                     {'label': 'STR',
#                      'values': array([94., 84., 92., 89., 83., 94., 84., 92., 89., 83., 83., 89., 83., 88.,
#                                       85., 81., 82., 90., 80., 86.])},
#                     {'label': 'AGI',
#                      'values': array([52., 73., 50., 63., 55., 52., 73., 50., 63., 55., 47., 51., 58., 71.,
#                                       65., 56., 43., 48., 69., 51.])}],
#      'marker': {'line': {'color': 'rgb(0,50,240)', 'width': 0.5}, 'showscale': False, 'size': 6},
#      'name': 'RT',
#      'showupperhalf': False,
#      'text': array(['Willie Anderson', 'Lane Johnson', 'Willie Anderson', 'Marcus Cannon',
#                     'Demar Dotson', 'Willie Anderson', 'Lane Johnson', 'Willie Anderson',
#                     'Marcus Cannon', 'Demar Dotson', 'Daryl Williams', 'Willie Anderson',
#                     'Jermey Parnell', 'Ryan Ramczyk', 'Bryan Bulaga', 'Jack Conklin',
#                     'Rob Havenstein', 'Willie Anderson', 'Lane Johnson', 'Willie Anderson'],
#                    dtype=object),
#      'uid': 'a7f383e2-eb50-11e8-a2ca-8c85907f6380'
#  }))
